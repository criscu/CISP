# %% [markdown]
# # Imports

# %%
import openai
import pandas as pd
import json
import string
import gensim.downloader as api
import numpy as np
import time
from openai.embeddings_utils import pca_components_from_embeddings

# %%
def request_gpt(prompt: str = '', content: str = ''):
    """
    Wrapper that calls OpenAI's API to generate a response based on a system prompt and a body of text.

    system_prompt: str
    body: str

    return: str
    """
    _body = prompt + content
    res = openai.ChatCompletion.create(
        model='gpt-4',
        messages=[{'role': 'user', 'content': _body}]
    )
    return res.choices[0].message.content

# %%
# Load "credentials.json" which contains the value "open_ai_key"
openai.api_key = json.load(open("credentials.json"))["open_ai_key"]

# %%
# Load the data

corpus = pd.read_csv('CORPUS_ICPB.csv', index_col=0)
corpus
# Out:
#        modifyAt                   createAt
# 0           NaN  2023-01-31 17:33:43+00:00  \
# 1           NaN  2023-01-31 17:33:43+00:00
# 2           NaN  2023-01-31 17:33:43+00:00
# 3           NaN  2023-01-31 17:33:43+00:00
# 4           NaN  2023-01-31 17:33:43+00:00
# ...         ...                        ...
# 32315       NaN  2023-04-11 14:53:18+00:00
# 32316       NaN  2023-04-11 14:53:18+00:00
# 32317       NaN  2023-04-11 14:53:18+00:00
# 32318       NaN  2023-04-11 14:53:18+00:00
# 32319       NaN  2023-04-11 14:53:18+00:00
#
#                                                    titre               source
# 0      Versailles: un "expert en masculinité" condamn...                BFMTV  \
# 1      Finistère: un homme agresse un policier en lui...                BFMTV
# 2      Grève du 31 janvier : à quelles perturbations ...           LePoint.fr
# 3      Puy-de-Dôme: une jeune femme tuée par balle, s...                BFMTV
# 4      Le gouvernement demande le retrait de toutes l...                BFMTV
# ...                                                  ...                  ...
# 32315  Casinos Barrière : Alexandre Barrière, fils du...           LePoint.fr
# 32316  Enseignants : une revalorisation salariale « e...  Journal du Dimanche
# 32317  Affaire Crédit lyonnais : Bernard Tapie aurait...  Journal du Dimanche
# 32318  Finistère : Prison ferme pour des Bosniens qui...         20minutes.fr
# 32319  Un étudiant sur deux se sent en insécurité fac...                BFMTV
#
#        idArticle                                              texte
# 0              0  Des dossiers au tribunal de Versailles, dans l...  \
# 1              1  Deux policiers ont été violemment agressés par...
# 2              2  La première journée de grève, jeudi 19 janvier...
# 3              3  (Voiture de police française) - Bertrand GUAY ...
# 4              4  Couloir d'hôpital. (Photo d'illustration) - JU...
# ...          ...                                                ...
# 32315      16173  Alexandre Barrière, âgé de 36 ans, est le fils...
# 32316      16174  Le ministre de l’Éducation nationale, Pap Ndia...
# 32317      16175  Le Consortium de réalisation (CDR) commence à ...
# 32318      16176  ARNAQUE - Une centaine de victimes ont été rec...
# 32319      16177  Dans son baromètre 2023, l'Observatoire étudia...
#
#                             date                   auteur
# 0      2023-01-25 16:43:00+00:00                       AL  \
# 1      2023-01-25 16:02:00+00:00        Justine Chevalier
# 2      2023-01-25 14:46:00+00:00       Par Thibaut Déléaz
# 3      2023-01-25 14:36:00+00:00  Mélanie Vecchio avec AL
# 4      2023-01-25 14:30:00+00:00                     J.F.
# ...                          ...                      ...
# 32315  2023-04-11 14:51:17+00:00         Par L.L avec AFP
# 32316  2023-04-11 14:51:36+00:00                    leJDD
# 32317  2023-04-11 14:51:57+00:00                    leJDD
# 32318  2023-04-11 14:52:51+00:00            J.G. avec AFP
# 32319  2023-04-11 14:53:08+00:00            Salomé Robles
#
#                                                  vecteur
# 0      [0.47458213567733765, -0.189848855137825, -0.0...
# 1      [0.17718319594860077, -0.5617039799690247, -0....
# 2      [-0.2377959042787552, -0.08118520677089691, 0....
# 3      [0.24410541355609894, -0.2210969179868698, -0....
# 4      [0.3187011480331421, 0.20401036739349365, 0.06...
# ...                                                  ...
# 32315                                                NaN
# 32316                                                NaN
# 32317                                                NaN
# 32318                                                NaN
# 32319                                                NaN
#
# [32320 rows x 9 columns]

# %% [markdown]
# # Pre-processing

# %%
### Pre-processing of the data

# Drop some columns (modifyAt, createAt, idArticle, vecteur) which cannot be used
df = corpus[["titre", "source", "texte", "date", "auteur"]]

# Drop duplicated rows
df = df.drop_duplicates()

# Remove NaN values (In this case we remove a row if any NaN in it)
df = df.dropna()

# Create the column content which is the aggregation of title and text
df["content"] = "Titre: " + df["titre"]+ "\nContenu: " + df["texte"]

# Reset index
df.reset_index(drop=True, inplace=True)

# Save
df.to_csv('dataset_preprocessed.csv', index=False)

# %% [markdown]
# # Financial data filter

# %%
# Setup
FILTER_PROMPT = """

Write 1 if the following article is about finance or can impact the stock market, else 0:

--

"""

i_finance = 0 # Index of the row to process
df['is_finance'] = None # Creation of a new column which is True if related to Finance, else False
n_limit_finance = 1000 # Number of rows

# %%
# Creation of a new column which is True if related to Finance, else False
while i_finance<n_limit_finance and i_finance<len(df):
    try:
        print("Request on the {}th row".format(i_finance))
        content = df.content.iloc[i_finance]
        res = request_gpt(prompt=FILTER_PROMPT, content=content)
        _bool = bool(int(res))
        df['is_finance'][i_finance] = _bool
        i_finance+=1
    except Exception as e:
        print("Something went wrong:\n\n" + str(e))
        time.sleep(2)
# Out:
# Request on the 901th row
# Request on the 902th row
# Request on the 903th row
# Request on the 904th row
# Request on the 905th row
# Request on the 906th row
# Request on the 907th row
# Request on the 908th row
# Request on the 909th row
# Request on the 910th row
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[194], line 6
#       4 print("Request on the {}th row".format(i_finance))
#       5 content = df.content.iloc[i_finance]
# ----> 6 res = request_gpt(prompt=FILTER_PROMPT, content=content)
#       7 _bool = bool(int(res))
#       8 df['is_finance'][i_finance] = _bool
#
# Cell In[5], line 11, in request_gpt(prompt, content)
#       2 """
#       3 Wrapper that calls OpenAI's API to generate a response based on a system prompt and a body of text.
#       4
#    (...)
#       8 return: str
#       9 """
#      10 _body = prompt + content
# ---> 11 res = openai.ChatCompletion.create(
#      12     model='gpt-4',
#      13     messages=[{'role': 'user', 'content': _body}]
#      14 )
#      15 return res.choices[0].message.content
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/finance/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/envs/finance/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/finance/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/finance/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/finance/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/finance/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df_finance = df[df.is_finance == True].reset_index(drop=True)
df_finance.to_csv("dataset_finance.csv", index=False)
df_finance
# Out:
#                                                  titre             source
# 0    Grève du 31 janvier : à quelles perturbations ...         LePoint.fr  \
# 1    Chômage : une baisse de 3,6 % au quatrième tri...         LePoint.fr
# 2    Le Vatican définit l’investissement chrétien e...         Challenges
# 3    Surtaxe d’habitation : découvrez les villes qu...            Capital
# 4    Intergénérationnel : Focus sur les nombreux pr...             Zinfos
# ..                                                 ...                ...
# 382  Assemblée nationale : Cyrielle Chatelain, l’in...         20 Minutes
# 383  L'Ukraine tente de réparer ses sites énergétiq...  Euronews français
# 384  Avec la flambée des prix de l'énergie, le chif...         La Tribune
# 385  Guerre en Ukraine : des démocrates américains ...          L'Express
# 386  Croisières : le MSC World Europa, le paquebot ...         La Tribune
#
#                                                  texte
# 0    La première journée de grève, jeudi 19 janvier...  \
# 1    Le nombre de chômeurs en France s'élève à à 3,...
# 2    LES MARCHÉS AUJOURD'HUI\nPX1\n▼ -0,54%\nPX4\n▼...
# 3    LES MARCHÉS AUJOURD'HUI\nPX1\n▼ -1,44%\nPX4\n▼...
# 4    LES MARCHÉS AUJOURD'HUI\nPX1\n▲ +0,60%\nPX4\n▲...
# ..                                                 ...
# 382  La jeune présidente du groupe écologiste à l’A...
# 383  Les autorités ukrainiennes tentent d'atténuer ...
# 384  L'avenir s'annonce radieux pour Air Liquide qu...
# 385  Le président américain fait face à des critiqu...
# 386  Le MSC World Europa mesure 333 mètres de long,...
#
#                           date                     auteur
# 0    2023-01-25 14:46:00+00:00         Par Thibaut Déléaz  \
# 1    2023-01-25 13:24:00+00:00                 Source AFP
# 2    2022-05-12 17:21:08+00:00          Article de Pierre
# 3    2022-12-16 16:36:45+00:00            Article de Jean
# 4    2022-12-19 16:40:40+00:00  Article de Ville de Saint
# ..                         ...                        ...
# 382  2023-02-19 12:25:00+00:00   Rachel Garrat Valcarcel
# 383  2023-02-20 08:47:32+00:00                  Euronews
# 384  2023-02-20 08:47:32+00:00              latribune.fr
# 385  2023-02-20 08:47:32+00:00               lexpress.fr
# 386  2023-02-20 06:47:32+00:00              latribune.fr
#
#                                                content is_finance
# 0    Titre: Grève du 31 janvier : à quelles perturb...       True
# 1    Titre: Chômage : une baisse de 3,6 % au quatri...       True
# 2    Titre: Le Vatican définit l’investissement chr...       True
# 3    Titre: Surtaxe d’habitation : découvrez les vi...       True
# 4    Titre: Intergénérationnel : Focus sur les nomb...       True
# ..                                                 ...        ...
# 382  Titre: Assemblée nationale : Cyrielle Chatelai...       True
# 383  Titre: L'Ukraine tente de réparer ses sites én...       True
# 384  Titre: Avec la flambée des prix de l'énergie, ...       True
# 385  Titre: Guerre en Ukraine : des démocrates amér...       True
# 386  Titre: Croisières : le MSC World Europa, le pa...       True
#
# [387 rows x 7 columns]

# %% [markdown]
# # Extraction of variables

# %%
# Setup
EXTRACTION_PROMPT = """

Votre tâche consiste à trouver des variables pertinentes dans un article de finance. Essayez de donner des noms de variables génériques, qui seront également identifiables dans d'autres textes.
J'aimerais que vous identifiiez une tendance dans l'article qui sera la variable résultat, que nous appellerons "Indicateur". Cet "Indicateur" sera l'un des trois termes suivants : "POSITIF", "NEUTRE" ou "NEGATIF", selon le sentiment de l'article sur les cours et indices boursiers, les tendances du marché, etc.

Par exemple, si vous voyez :
Lorsqu'une entreprise connaît une baisse importante de ses bénéfices ou une réduction de son activité, elle peut être contrainte de réduire ses effectifs en procédant à des licenciements ou en gelant les embauches, ce qui peut contribuer à une augmentation du taux de chômage dans la région où elle est implantée. 
Nous vous demandons d'extraire : la situation financière de l'entreprise, les décisions de l'entreprise, le taux de chômage, le cours de l'action de l'entreprise.

Vous ne devez renvoyer qu'une chaîne de caractères au format JSON suivant :
{
    "Indicateur" : "valeur 0",
    "Situation Financière de l'Entreprise" : "valeur 1",
    "Décisions de l'Entreprise" : "valeur 2",
    ...
}
où les valeurs sont les mots trouvés dans l'article en rapport avec la variable extraite.

Voici l'article à analyser :

---

"""

i_extraction = 0 # Index of the row to process
df_finance['extraction'] = None # Creation of a new column "extraction" which contains a dict. keys are variables and values are text from the article related to the variable

n_limit_extraction = 400

# %%
while i_extraction<n_limit_extraction and i_extraction<len(df_finance):
    try:
        print("Request on the {}th row".format(i_extraction))
        content = df_finance.content.iloc[i_extraction]
        res = request_gpt(prompt=EXTRACTION_PROMPT, content=content)
        _json = json.loads(res.replace("\n", ""))
        df_finance['extraction'][i_extraction] = _json
        i_extraction+=1
    except Exception as e:
        print("Something went wrong:\n\n" + str(e))
        time.sleep(5)

# %%
df_finance.to_csv("dataset_extract.csv", index=False)
df_finance
# Out:
#                                                  titre             source
# 0    Grève du 31 janvier : à quelles perturbations ...         LePoint.fr  \
# 1    Chômage : une baisse de 3,6 % au quatrième tri...         LePoint.fr
# 2    Le Vatican définit l’investissement chrétien e...         Challenges
# 3    Surtaxe d’habitation : découvrez les villes qu...            Capital
# 4    Intergénérationnel : Focus sur les nombreux pr...             Zinfos
# ..                                                 ...                ...
# 382  Assemblée nationale : Cyrielle Chatelain, l’in...         20 Minutes
# 383  L'Ukraine tente de réparer ses sites énergétiq...  Euronews français
# 384  Avec la flambée des prix de l'énergie, le chif...         La Tribune
# 385  Guerre en Ukraine : des démocrates américains ...          L'Express
# 386  Croisières : le MSC World Europa, le paquebot ...         La Tribune
#
#                                                  texte
# 0    La première journée de grève, jeudi 19 janvier...  \
# 1    Le nombre de chômeurs en France s'élève à à 3,...
# 2    LES MARCHÉS AUJOURD'HUI\nPX1\n▼ -0,54%\nPX4\n▼...
# 3    LES MARCHÉS AUJOURD'HUI\nPX1\n▼ -1,44%\nPX4\n▼...
# 4    LES MARCHÉS AUJOURD'HUI\nPX1\n▲ +0,60%\nPX4\n▲...
# ..                                                 ...
# 382  La jeune présidente du groupe écologiste à l’A...
# 383  Les autorités ukrainiennes tentent d'atténuer ...
# 384  L'avenir s'annonce radieux pour Air Liquide qu...
# 385  Le président américain fait face à des critiqu...
# 386  Le MSC World Europa mesure 333 mètres de long,...
#
#                           date                     auteur
# 0    2023-01-25 14:46:00+00:00         Par Thibaut Déléaz  \
# 1    2023-01-25 13:24:00+00:00                 Source AFP
# 2    2022-05-12 17:21:08+00:00          Article de Pierre
# 3    2022-12-16 16:36:45+00:00            Article de Jean
# 4    2022-12-19 16:40:40+00:00  Article de Ville de Saint
# ..                         ...                        ...
# 382  2023-02-19 12:25:00+00:00   Rachel Garrat Valcarcel
# 383  2023-02-20 08:47:32+00:00                  Euronews
# 384  2023-02-20 08:47:32+00:00              latribune.fr
# 385  2023-02-20 08:47:32+00:00               lexpress.fr
# 386  2023-02-20 06:47:32+00:00              latribune.fr
#
#                                                content  is_finance
# 0    Titre: Grève du 31 janvier : à quelles perturb...        True  \
# 1    Titre: Chômage : une baisse de 3,6 % au quatri...        True
# 2    Titre: Le Vatican définit l’investissement chr...        True
# 3    Titre: Surtaxe d’habitation : découvrez les vi...        True
# 4    Titre: Intergénérationnel : Focus sur les nomb...        True
# ..                                                 ...         ...
# 382  Titre: Assemblée nationale : Cyrielle Chatelai...        True
# 383  Titre: L'Ukraine tente de réparer ses sites én...        True
# 384  Titre: Avec la flambée des prix de l'énergie, ...        True
# 385  Titre: Guerre en Ukraine : des démocrates amér...        True
# 386  Titre: Croisières : le MSC World Europa, le pa...        True
#
#                                             extraction
# 0    {'Indicateur': 'NEGATIF', 'Situation Politique...
# 1    {'Indicateur': 'POSITIF', 'Taux de Chômage': '...
# 2    {'Indicateur': 'NEUTRE', 'Normes d'Investissem...
# 3    {'Indicateur': 'NEUTRE', 'Situation Financière...
# 4    {'Indicateur': 'POSITIF', 'Performance des Mar...
# ..                                                 ...
# 382  {'Indicateur': 'NEUTRE', 'Rôle des Acteurs Pol...
# 383  {'Indicateur': 'NEGATIF', 'Situation Politique...
# 384  {'Indicateur': 'POSITIF', 'Situation Financièr...
# 385  {'Indicateur': 'NEUTRE', 'Situation Politique'...
# 386  {'Indicateur': 'POSITIF', 'Taille du Navire': ...
#
# [387 rows x 8 columns]

# %% [markdown]
# # Reducing the number of variables

# %%
# Creation of a ChatGPT request which takes the list of all extracted variables and create a dict with more global variables as key and the extracted variables as values

# Setup
REDUCTION_PROMPT = """

Je vais te donner une liste de variables. Regroupe les variables en groupes. Les variables peuvent être représentées dans un ou plusieurs groupes.
N'oublie aucune variable. Je veux que toutes les variables soient représentées dans des catégories, tu ne dois pas en laisser de côté.

---

Par exemple, si je te donne "Manifestation", "Accident", "Taux de pauvreté", "Taxe carbone"...
Tu dois créer le dictionnaire suivant :
{
    "Social" : ["Manifestation", "Accident", "Taux de pauvreté",...],
    "Economique" : ["Taux de pauvreté",...],
    "Travail" : ["Manifestation"],
    "Entreprise" : ["Taxe carbone",...]
    "Environnement" : ["Taxe carbone",...]
    ...
}

---

"Indicateur" est une catégorie. Essaie de regrouper la liste en moins de 10 catégories. Envoie uniquement le dictionnaire.

Ci-dessous la liste des variables :

"""

# %%
# Creation of the list of all variables
variables_list = []
for row in df_finance.iterrows():
    try:
        _dict = row[1].extraction.copy()
        _dict.pop("Indicateur")
        variables_list+= list(_dict.keys())
    except:
        pass
variables_list
# Out:
# ['Situation Politique',
#  'Décisions Syndicales',
#  'Mobilisation Citoyenne',
#  'Répercussions sur les Transports',
#  'Prévisions Syndicales',
#  'Taux de Chômage',
#  'Nombre de Chômeurs',
#  'Changement par rapport au Trimestre Précédent',
#  'Comparaison Historique',
#  "Nombre de Demandeur d'Emploi (incluant activité réduite)",
#  "Normes d'Investissement",
#  'Décisions de la Commission Européenne',
#  'Montant des Investissements',
#  'Publication du Vatican',
#  'Valeur du Document Vatican',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Communes",
#  'Marché Immobilier',
#  'Réglementations Financières',
#  "Taux d'Impôt",
#  'Performance des Marchés',
#  'Politique de la Commune',
#  'Projets de la Commune',
#  'Décision Politique',
#  'Crise Alimentaire',
#  'Opposition Politique',
#  'Climat',
#  'Situation du Pays',
#  'Résultats Élections',
#  'Situation Politique',
#  'Intentions de vote',
#  'Impact événements externes',
#  'Soutiens politiques',
#  'Situation Politique et Sociale du Pays',
#  'Actions du Gouvernement',
#  'Impact sur les Citoyens',
#  "Situation Financière de l'Entreprise",
#  'Tendance du marché',
#  "Politique d'entreprise",
#  'Niveau de maturité des organisations',
#  "Niveau d'implication des entreprises",
#  'Position Diplomatique',
#  'Rôle des Organisations Internationales',
#  'Actions et Décisions des États',
#  'Personnages Importants',
#  'Tension Diplomatique',
#  'Décisions Politiques',
#  'Consensus Politique',
#  'Changement Climatique',
#  'Evénements Climatiques Extrêmes',
#  'Institutions Concernées',
#  'Réponse Publique et Actions',
#  'Données et Records Climatiques',
#  'Planification de François Braun',
#  'À destination des Soignants',
#  'Mesures pour les soins',
#  'Revalorisation des tarifs médecins libéraux',
#  'Médecins Intérimaires à l’hôpital',
#  'Restructuration dans le secteur de la santé',
#  'Mobilisation des Citoyens',
#  'Politique de Retraite',
#  'Position des Partis Politiques',
#  'Décisions du Gouvernement',
#  'Opposition des Citoyens',
#  'Déclaration des Personnalités Politiques',
#  'Activités des Députés',
#  'Marché Boursier',
#  'Initiatives Publiques',
#  'Public Cible',
#  "Montant d'Aide",
#  "Modalités d'Obtention",
#  'Taux de change EUR/USD',
#  'Taux de change EUR/GBP',
#  'Actions de marché PX1',
#  'Actions de marché PX4',
#  'Actions de marché CACAS',
#  "Programme d'Assistance Municipale",
#  'Groupe cible',
#  'Exigences du programme',
#  'Limite de subvention',
#  "Réputation de l'Individu",
#  "Actions de l'Individu",
#  'Sanctions',
#  'Accusations',
#  'Victime',
#  'Violations légales',
#  'Politique Nationale',
#  "Activité de l'Assemblée",
#  'Décisions Politiques',
#  'Date',
#  'Décisions Politiques',
#  'Évolution Législative',
#  'Impacts Financiers',
#  'Réactions des Organisations',
#  'Prix du Produit',
#  'Comparaison des Prix',
#  'Tarifs du Produit',
#  'Bonus à l’Achat',
#  'Caractéristiques du Produit',
#  'Autonomie du Produit',
#  "Comparaison de l'Autonomie",
#  'Situation Politique',
#  'Evènements de Sécurité',
#  'Décisions du Gouvernement',
#  'Dommages',
#  'Décisions Politiques',
#  'Contexte Économique',
#  'Impact entrepreneurial',
#  'Taxes et Impôts',
#  'Mesures Gouvernementales',
#  'Situation Politique',
#  'Stabilité du Réseau Électrique',
#  'Projet Gazier',
#  'Évacuation des Civils dans les Régions Occupées',
#  "Impact des Bombardements sur l'Infrastructure",
#  'Organisation Internationale',
#  'Partenariat International',
#  'Initiative de Défense',
#  'Véhicule de Défense',
#  'Déclarations Officielles',
#  'Situation Géopolitique',
#  'Financement de la Défense',
#  'Armement',
#  'Relations Economiques Internationales',
#  'Projets Énergétiques',
#  'Décisions Politiques',
#  'Commerce International',
#  'Situation Politique',
#  'Attaques Militaires',
#  'Aide aux Ukrainiens',
#  'Targeting des Attaques',
#  'Déclarations Politiques',
#  'Aide Matérielle',
#  "Intervention de l'ONU",
#  'Décisions de la Personne Concernée',
#  'Actions des Autorités',
#  'Actions de la Personne Concernée',
#  'Enquête en Cours',
#  'Documents Trouvés',
#  'Decisions Gouvernementales',
#  'Activité Politique',
#  'Stratégies Fiscales',
#  "Taux d'Imposition",
#  'Impact Economique',
#  'Politique Gouvernementale',
#  "Décisions de l'Entreprise",
#  'Budget',
#  'Prix des Produits',
#  'Impôts des Entreprises',
#  'Politique Macron',
#  'Situation Financière Exceptionnelle',
#  "Situation Financière de l'Etat",
#  'Décisions Politiques',
#  'Politique de dépenses',
#  "Paroles d'un Responsable Politique",
#  "Responsabilité de l'Entreprise",
#  'Décisions Juridiques',
#  "Image d'Entreprise",
#  "Conséquences d'Entreprise",
#  'Opinions Publiques',
#  'Evènements Politiques',
#  'Evènements Ecologiques',
#  'Production Energétique',
#  'Mouvement Contestataire',
#  'Impact sur la Science',
#  'Personnages Médiatiques',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Secteur Economique',
#  'Taux de Décès',
#  'Responsabilité de Gestion des Défunts',
#  'Tendances du Marché',
#  'Régulations',
#  'Situation politique et militaire',
#  'Rôle des civils',
#  'Conséquences du conflit',
#  'Objectifs de la guerre',
#  'Conditions de combat',
#  'Résultats Sondage',
#  'Evolution des scores',
#  'Second Tour Hypothétique',
#  'Gestion des affaires',
#  'Situation Politique Globale',
#  "Décisions de l'Exécutif",
#  'Relations Interparties',
#  'Position du Gouvernement',
#  'Difficultés Politiques du Gouvernement',
#  'Position Politique des Partis',
#  'Alignement des Votes',
#  'Leaders Politiques',
#  'Alliances Politiques',
#  'Actions gouvernementales',
#  'Enjeux environnementaux',
#  'Investissements et moyens alloués',
#  'Impacts et conséquences',
#  'Situation Politique du Pays',
#  'Situation Économique du Pays',
#  'Politiques du Gouvernement',
#  'Soutien Politique',
#  'Situation Politique du Pays',
#  "Décisions du Chef de l'Etat",
#  'Conflits Politiques',
#  'Conflits et Guerres',
#  "Infrastructure de l'Energie et Impact",
#  'Impact Economique',
#  'Implication Politique',
#  'Situation du Marché',
#  'Effets sur les pays en besoin',
#  'Exportations de céréales',
#  "Décisions de l'Entreprise",
#  "Situation Politique de l'Entreprise",
#  'Santé du Leader',
#  "Perspective d'avenir",
#  "Réputation de l'Entreprise",
#  'Situation Géopolitique',
#  "Effets sur l'Infrastructure",
#  'Rôle des autorités',
#  'Tensions politiques internationales',
#  'Installations énergétiques',
#  'Actions militaires',
#  'Acteurs Politiques',
#  'Tendance des Marchés',
#  'Objectif Environnemental de la France',
#  'Performance Environnementale de la France',
#  'Investissement Nécessaire pour la Transition Énergétique',
#  'Implications pour les Entreprises',
#  'Implications pour les Ménages',
#  "Rôle de l'Etat",
#  "Situation Financière de l'Etat",
#  "Décisions de l'Etat",
#  'Politique Environnementale',
#  'Objectifs Etablis',
#  'Manifestation',
#  'Situation géographique',
#  'Conflit',
#  'Manifestants',
#  'Mesures gouvernementales',
#  'Projet contesté',
#  'Conséquences de la manifestation',
#  'Projet de Loi',
#  'Action du Gouvernement',
#  'Tendance Politique',
#  'Impact sur le Climat',
#  'Oppositions et Défis',
#  'Outils Administratifs',
#  'Acteurs Internationaux',
#  'Instituts et Organisations',
#  'Politiques Energie',
#  'Déclarations Officielles',
#  'Impact Economique',
#  'Intensité des Vagues de Chaleur',
#  'Coût des Vagues de Chaleur',
#  'Impact Économique des Vagues de Chaleur',
#  'Inégalités',
#  'Coût pour les Pays Pauvres',
#  "Raisons de l'Impact Économique Accru sur les Pays Pauvres",
#  'Compensations Envisagées',
#  'Débat sur le Changement Climatique',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de Chômage',
#  'Mouvements Syndicaux',
#  "Cours de l'Action de l'Entreprise",
#  'Ravitaillement et Production',
#  'Décisions Gouvernementales',
#  'Sécurité Alimentaire Mondiale',
#  'Relations Internationales',
#  'Exportations de Céréales Ukrainiennes',
#  'Projet de Loi',
#  'Communes concernées',
#  "Taxe d'habitation",
#  "Zones d'implantation",
#  "Possibilité d'échappatoire",
#  'Situation Politique du Pays',
#  "Décisions de l'Exécutif",
#  'Situation Politique des Partis',
#  'Décision Politique',
#  'Conséquences de la Décision Politique',
#  'Réaction Internationale',
#  'Accord International',
#  'Exportation des Céréales Ukrainiennes',
#  'Politique économique des Etats-Unis',
#  "Réaction de l'UE",
#  "Position du ministre tchèque de l'Industrie",
#  "Réponse de l'UE",
#  'Elections Politiques',
#  'Politiques Environnementales',
#  "Etat de l'Environnement",
#  'Collaborations Internationales',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de Chômage',
#  "Cours de l'Action de l'Entreprise",
#  'Revendications des Employés',
#  'Relations Entre Syndicats et Direction',
#  'Conditions de Travail',
#  'Questions de Sécurité',
#  'Interaction Entre Dirigeants',
#  'Conférence Internationale',
#  'Acteurs Impliqués',
#  "Aide d'Urgence et Effort Européen",
#  'Projet de loi gouvernement',
#  "Place de l'atome en France",
#  'Besoins en électricité',
#  "Stratégie d'Emmanuel Macron",
#  'Projet pour les énergies renouvelables',
#  'Examen du texte sur le nucléaire',
#  'Position du ministère de la Transition énergétique',
#  'Planned EPR',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Changements envisagés',
#  'Impact pour les salariés',
#  'Décisions de la Plateforme',
#  'Situation Financière de Twitter',
#  'Futurs Utilisateurs Certifiés',
#  'Coût du Service de Twitter',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de chômage',
#  "Cours de l'Action de l'Entreprise",
#  "Ambitions de l'Entreprise",
#  "Performances de l'Entreprise",
#  'Relations Internationales',
#  "Coût de l'Acquisition",
#  'Opération Financière',
#  'Outil de Politique Étrangère',
#  'Influence Economique',
#  'Soutien en Communications',
#  'Influence du Secteur Privé',
#  'Actions des PDG',
#  'Tensions Politiques',
#  'Rétractation de la Menace',
#  'Financement du Gouvernement Ukrainien',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Tendances du Marché',
#  'Technologies Impliquées',
#  'Produits/Services',
#  'Personnalités Mentionnées',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Prix de Vente',
#  "Performance de l'Entreprise",
#  'Acheteur',
#  'Estimation du Prix du Domaine',
#  'Décisions du Gouvernement',
#  'Inflation',
#  'Objectifs du Gouvernement',
#  'Dépenses Gouvernementales',
#  'Decisions du Gouvernement',
#  'Reactions Politiques',
#  'Situation Politique et Economique',
#  'Projet de Loi du Gouvernement',
#  "Planification d'Energie",
#  'Politique Energetique',
#  'Installations Nucléaires',
#  'Procédures Administratives',
#  "Communes d'Implantation",
#  'Part du Nucléaire dans le Mix Energetique',
#  'Energies Renouvelables',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Demandes du Syndicat',
#  'Impacts de la Grève',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Conditions de Travail',
#  "Opinions d'Experts",
#  'Situation Politique',
#  'Décisions du Président',
#  'Situation Sociale',
#  'Tendance électorale',
#  'Situation Politique',
#  "Décisions de l'Exécutif",
#  'Stratégies des Parties',
#  'Spéculations Politiques',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Taux de Taxe d'Habitation",
#  'Nombre de Communes Concernées',
#  'Position Géographique des Communes Concernées',
#  'Impact sur les Propriétaires',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de chômage',
#  "Cours de l'action de l'entreprise",
#  'Decisions Politiques',
#  'Déclarations des Parties Politiques',
#  'Rapport de la Cour de Comptes',
#  "Décisions de l'Entreprise",
#  'Crise internationale',
#  'Situation Politique',
#  "Contrat d'Exportation",
#  'Sécurité Alimentaire Mondiale',
#  'Cout de Certification Twitter',
#  "Décisions de l'Entreprise",
#  "Initiatives d'Elon Musk",
#  'Réactions de Bruno Le Maire',
#  'Sources de Revenus de Twitter',
#  "Décisions de l'institution gouvernementale",
#  'Programmation budgétaire',
#  'Position du gouvernement',
#  'Consequences potentielles',
#  'Situation Politique',
#  'Décisions gouvernementales',
#  'Décisions Judiciaires',
#  'Déclarations',
#  'Accusations',
#  'État de santé du dirigeant',
#  'Spéculation sur la santé du dirigeant',
#  'Mesures de sécurité du dirigeant',
#  'Situation Militaire sur le Terrain',
#  'Stratégie Militaire Utilisée',
#  'Decisions Politiques',
#  'Impact de la Guerre',
#  'Situation Géopolitique',
#  'Infrastructure Affectée',
#  'Acteurs',
#  'Conséquences',
#  'Situation Politique Internationale',
#  "Décisions de l'Entreprise",
#  'Situation Financière des Marchés Mondiaux',
#  'Noms des Scientifiques',
#  'Domaine de Recherche',
#  'Actions Entreprises',
#  'Actions Ciblées',
#  'Lieu',
#  'Prochaine Manifestation',
#  'Message',
#  'Tendance Climatique',
#  "Rapport de l'ONU",
#  'Changements Environnementaux',
#  'Impact sur le Niveau de la Mer',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Impact du Covid-19 sur l'Entreprise",
#  'Inflation',
#  'Consequences Personnelles pour le Propriétaire',
#  "Performance de l'Entreprise",
#  "Innovation de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Situation de l'Entreprise",
#  "Produit de l'Entreprise",
#  "Acquisition d'Entreprise",
#  "Décisions de l'Entreprise",
#  'Information Erronée',
#  'Auteur de la Désinformation',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Effet sur les Employés',
#  'Effet sur les Utilisateurs',
#  'Stratégie de Monetisation',
#  "Changements d'Entreprise",
#  "Politique de l'Entreprise",
#  'Rôle de la Direction',
#  'Politique de Santé Publique',
#  'Décision Gouvernementale',
#  'Données Statistiques',
#  'Investissement du Gouvernement',
#  'Secteur Ciblé',
#  "Décisions de l'Etat",
#  'Problèmes Identifiés',
#  'Actions Précédentes',
#  'Planification Financière',
#  'Situation Sanitaire',
#  'Décisions des Autorités Médicales',
#  "Taux d'Infection",
#  'Recommandations',
#  'Situation Politique et Militaire',
#  'Conséquences Civiles',
#  'Réponse Internationale',
#  'Préoccupations Nucléaires',
#  'Situation Politique du Pays',
#  'Transition Gouvernementale',
#  'Plans de gouvernement futur',
#  'Evaluations de transition',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Mécanismes de contrôle',
#  'Enquête Judiciaire',
#  'Situation Politique',
#  'Décisions Politiques',
#  'Situation Internationale',
#  'Relations Économiques Internationales',
#  'Sujets Sensibles',
#  'Situation industrie automobile',
#  'Position des scientifiques',
#  'Arrestation des chercheurs',
#  'Réaction de la communauté scientifique',
#  'Impact environnemental',
#  'Proposition Gouvernementale',
#  'Effets Immigration sur Salaires',
#  'Problématique sur Attractivité Métiers',
#  'Demande Salariés',
#  'Proposition de Régulation des Salaires',
#  'Personnalités principales',
#  'Entreprise concernée',
#  "Décisions de l'entreprise",
#  'Conséquences',
#  'Gestion de Crise',
#  "Réputation de l'Entreprise",
#  'Incidence sur les Communications',
#  "Position Géopolitique d'Elon Musk",
#  'Impact Emotionnel et Perception Publique',
#  'Financement Réseau Starlink',
#  'Situation Politique internationale',
#  'Visites diplomatiques',
#  'Politique sanitaires',
#  'Coopération internationale',
#  'Réactions à la visite',
#  'Réchauffement Climatique',
#  'Impacts du Réchauffement Climatique',
#  'Zone Géographique Concernée',
#  'Rôle des Incendies',
#  'Effets sur le Climat',
#  'Conséquences Potentielles',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Marché de l'Entreprise",
#  'Exploitation des Ressources',
#  "Stratégie de l'Entreprise",
#  'Future Prévision de la Société',
#  'Investissements Financiers Potentiels',
#  'Emissions de Gaz à Effet de Serre',
#  'Transition Energétique',
#  'Analyse Financière',
#  'Aide Financière Internationale',
#  'Stratégie de la Banque Mondiale',
#  'Réchauffement Climatique',
#  'Ambitions de Développement',
#  'Implication Financière',
#  "Pourcentage D'Augmentation Des Candidats LGBTQ",
#  'Nombre de Candidats LGBTQ',
#  'Rôles Politiques Visés',
#  'Pourcentage De Candidats LGBTQ Démocrates',
#  'Attitudes Politiques Vers Les Droits LGBTQ',
#  'Nouvelle infrastructure',
#  'Localisation',
#  'Tendance',
#  'Infrastructure future',
#  'Méthodes de paiement',
#  'Investissement gouvernemental',
#  'Secteur bénéficiaire',
#  'Crise sectorielle',
#  'Décisions gouvernementales',
#  'Réponse aux revendications',
#  'Mesures financières prévues',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de Chômage',
#  "Cours de l'Action de l'Entreprise",
#  'Avancements Technologiques',
#  'Investissements et Missions Spatiales',
#  'Objectifs et Résultats de la Mission',
#  'Études et Recherches Planifiées',
#  'Conflit en Ukraine',
#  'Pertes russes',
#  'Préparations russes',
#  'Prévision des attaques russes',
#  'Rencontre Diplomatique',
#  'But de la Visite',
#  'Déclarations Politiques',
#  'Relations Internationales',
#  'Changement de Position',
#  'Demandes Politiques',
#  'Presse et perception',
#  'Négociations Commerciales',
#  'Enjeux Climatiques Mondiaux',
#  'Engagements des Gouvernements',
#  'Situation Économique Globale',
#  'Conséquences de Crises Multiples',
#  'Effets du Réchauffement Climatique',
#  'Décisions des Gouvernements sur le Climat',
#  'Émissions de Gaz à Effet de Serre',
#  'Population Mondiale',
#  'Surconsommation des Ressources',
#  'Impact Environnemental',
#  'Ressources Naturelles',
#  'Décisions Humaines',
#  'Cote de Popularité du président sud-coréen',
#  'Évaluation de la conduite des affaires publiques',
#  'Soutien au parti conservateur au pouvoir',
#  "Cote de popularité du principal parti d'opposition",
#  'Soutien au parti progressiste mineur',
#  'Résultats du sondage',
#  'Politiques Publiques',
#  'Actions des États',
#  'Tendances',
#  'Impact Potentiel',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Marché Financier',
#  'Tendance du Marché',
#  'Risques',
#  'Résultats des Élections',
#  'Relations Internationales',
#  'Formation du Gouvernement',
#  'Inquiétudes',
#  'Tendances du Marché',
#  'Événements Politiques',
#  'Relations Commerciales Internationales',
#  'Acteurs du Marché',
#  'Performance des Indices Boursiers',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de Chômage',
#  "Cours de l'Action de l'Entreprise",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de chômage',
#  "Cours de l'action de l'Entreprise",
#  'Tendances du marché',
#  'Autres énergéticiens',
#  'Phénomène Climatique',
#  'Impact Environnemental',
#  'Rapport et Indicateurs Scientifiques',
#  'Réactions et Actions Politiques',
#  'Principaux objectifs de la conférence',
#  'Engagements des pays signataires',
#  'Rapport du GIEC',
#  'Rôles des états',
#  'Enjeux des pays en développement',
#  'Financements climat',
#  'Condition Climatique',
#  'Rapports et Organisations',
#  'Impacts Environnementaux',
#  'Réactions et Perspectives',
#  'Changement Climatique',
#  'Secteur Viticole',
#  'Association pour la reconnaissance des vins bretons',
#  'Production de Vin',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Position de Leader',
#  "Perspective d'avenir",
#  'La charge de travail',
#  'Emploi',
#  'Sens de Commerce',
#  'Réalités Politiques',
#  'Décisions Politiques',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Impact Social',
#  "Cours de l'Action de l'Entreprise",
#  "Propriétaire de l'Entreprise",
#  "Développement d'applications santé",
#  "Usage de l'Espace Santé numérique",
#  'Coût des applications',
#  'Influence des réseaux sociaux sur les élections',
#  'Mauvaise pratique de TikTok',
#  'Impact de la désinformation sur le vote',
#  "Résultats de l'étude",
#  'Opinion Publique',
#  'Stabilité Politique',
#  'Actions Gouvernementales',
#  'Discussion entre les Présidents',
#  'Situation du Conflit',
#  'Armes Nucléaires',
#  'Position des Partis Politiques',
#  "Décisions de l'Exécutif",
#  "Sentiments des Partis d'Opposition",
#  "Démarches de l'Exécutif",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Ventes et Profits',
#  'Tendance du Marché',
#  "Opinions d'Experts",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Taux d'Imposition",
#  'Public Visé',
#  'Exemptions',
#  'Conséquences Financières pour le Public',
#  "Comparaison des Taux d'Imposition",
#  "Prévisions d'Investissement",
#  'Recettes Prévues',
#  'Endettement Prévu',
#  'Situation Géopolitique',
#  'Loi Martiale',
#  'Contrôle des Territoires',
#  'Témoignages Locaux',
#  'Action des Troupes Russes',
#  'Propagande des Médias',
#  'Situation Géopolitique',
#  'Aide Internationale',
#  'Attitude de la Russie',
#  "Position de l'Ukraine",
#  'Engagement des États-Unis',
#  'Bombardements Russes',
#  'Conflit Territoriaire',
#  'Incidents',
#  'Négociations',
#  'Impact',
#  'Déclarations officielles',
#  'Engagements',
#  'Politique Étrangère et Relations Internationales',
#  'Réactions Officielles et Communiqués de Presse',
#  'Situation Géostratégique et Militaire',
#  'Affirmations et Dénis',
#  'Dynamique de Négociation',
#  'Stratégies de Défense',
#  'Efforts Diplomatiques et Négociations',
#  'Situation Sociale Locale',
#  'Situation Environnementale',
#  'Position du Gouvernement',
#  'Situation des Touristes',
#  'Situation Diplomatique',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Conférence des Nations Unies',
#  'Résolution Climatique',
#  'Accords Environnementaux',
#  "Présence des Chefs d'État et de Gouvernement",
#  "Lieu de l'Événement",
#  "Agenda de l'Événement",
#  'Crises mondiales en cours',
#  'Problèmes environnementaux',
#  'Engagements Écologiques du Gouvernement',
#  'Politique de Lutte Contre le Changement Climatique',
#  'Orientation Ecologique',
#  'Performance du marché',
#  'Analyse du marché',
#  'Tendances technologiques sur le marché',
#  "Opinion/Stratégie d'entreprise",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Réaction des Employés',
#  'Opinion Publique',
#  'Impact sur les Utilisateurs',
#  'Etat de la Désinformation',
#  'Influence des Fake News',
#  "Pratique de l'Entreprise",
#  'Effet des Hackers',
#  "Résultats de l'Expérience",
#  "Opinion de l'Expert",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Transaction Financière',
#  'Acteurs Concernés',
#  'Prévenu Principal',
#  "Position du Chef d'Etat",
#  'Engagement de la France',
#  "Action du Chef d'Etat",
#  'Visions pour les Océans',
#  'Cadre Légal des Océans',
#  'Demande des Députés et Associations',
#  "Proposition à l'Assemblée Nationale",
#  'Politiques Économiques',
#  'Impacts Environnementaux',
#  'Technologies',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Tendances du Marché',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de Chômage',
#  "Cours de l'Action de l'Entreprise",
#  "Evolution du Rôle de l'Entreprise",
#  "Stratégie de l'Entreprise",
#  'Nouvelles Offres',
#  'Régulation',
#  'Tendances Sectorielles',
#  'Situation Geopolitique',
#  'Actions Militaires',
#  'Décisions Politiques',
#  'Tendance',
#  'Situation Politique Internationale',
#  'Décisions des Gouvernements',
#  "Position de l'Entreprise",
#  'Situation Economique Régionale',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Politiques Environnementales',
#  'Technologies utilisées',
#  'Pression Politique',
#  "Risques d'Entreprise",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Emprunts des Villes',
#  'Politiques Environnementales',
#  'Actions Climatiques',
#  'Engagements des Banques',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Environnement de l'Entreprise",
#  'Politique Gouvernementale',
#  'Emissions Polluantes',
#  'Décisions Politiques',
#  "Position de l'Entreprise/France",
#  'Projet(s) à venir',
#  'Collaborations Internationales',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  "Taux d'Impôt",
#  'Public Cible',
#  'Impact sur les Propriétaires',
#  "Comparatif avec d'Autres Villes",
#  "Reaction de l'Elu Local",
#  'Crises qui ont Impacté la Situation',
#  'Objectifs de la Décision',
#  "Prévision d'Investissement pour 2023",
#  'Situation Politique du Président',
#  "Statut de l'Assemblée Nationale",
#  'Image de la France',
#  "Situation du Chef d'Etat",
#  'Stratégie Politique du Président',
#  'Performance du Parti Politique de Renaissance',
#  'Rumeurs Politiques',
#  'Situation Globale',
#  "Impact des Évènements Mondiaux sur l'Entreprise",
#  "Stratégies d'Entreprise",
#  "Performance de l'Entreprise en Afrique",
#  "Responsabilité de l'Entreprise",
#  'Défis Futurs',
#  'Élections et Vote',
#  'Décisions Politiques',
#  'Impact sur les Relations Internationales',
#  'Stratégie Gouvernementale',
#  'Décisions des Autorités Locales',
#  'Conflit et Sécurité',
#  'Propagande et Journalisme',
#  'Situation sur le Terrain',
#  'Besoin en Financement',
#  'Origine du Financement',
#  'Utilisation du Financement',
#  'Effets Economiques',
#  "Emissions de Gaz de l'Industrie",
#  "Contribution de l'Industrie aux Solutions climatiques",
#  'Émissions de Gaz à Effet de Serre',
#  "Nécessité pour les Entreprises de Participer à l'Effort Climatique",
#  "Réduction des Émissions de Gaz à Effet de Serre par l'Industrie",
#  "Neutralité Carbone de l'Industrie",
#  'Tendance des Émissions de Gaz à Effet de Serre',
#  'Situation Financière des Pays en Développement',
#  "Décisions de l'Entreprise ou du Pays",
#  'Conséquences du Changement Climatique',
#  'Promesses des Pays Riches',
#  'Doctrine économique',
#  'Politiques économiques générales',
#  'Question environnementale',
#  'Problèmes sociaux',
#  'Solution environnementale',
#  "Effet sur l'emploi",
#  'Objectif de croissance',
#  'Vision de la societe',
#  'Déficit Commercial',
#  'Importations',
#  'Exportations',
#  'Inflation',
#  'Prix des biens échangés',
#  "Balance commerciale de l'énergie",
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Incident Technique',
#  'Status du Problème',
#  'Affirmation sur la Capacité du Vaisseau',
#  'Ravitaillement',
#  'Expériences à bord',
#  "Actions de l'Autorité",
#  'Comportement des Partis Concernés',
#  "Transparence de l'Entreprise",
#  'Risques Potentiels',
#  'Atout pour la région',
#  'Projet et sa mise en oeuvre',
#  "Impact potentiel sur l'économie maritime",
#  'Évaluation de la situation actuelle',
#  'Fonds de Soutien Militaire aux Ukrainiens',
#  'Décisions du Gouvernement',
#  'Situation Politique et Militaire en Ukraine',
#  "Situation Financière de l'Entreprise",
#  "Evénements d'Entreprise",
#  'Chiffre d’affaires de l’entreprise',
#  "Contraintes d'entreprise",
#  'Perception Publique',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Transition de Leadership',
#  "Défis de l'Entreprise",
#  'Décisions Politiques',
#  'Représentants politiques impliqués',
#  "Tendance du Marché de l'Emploi",
#  "Décisions de l'entreprise",
#  "Innovations de l'entreprise",
#  "Situation financière de l'entreprise",
#  "Position de l'entreprise sur le marché",
#  'Situation Politique',
#  'Prospectives',
#  "Issues d'Election",
#  'Engagement Public',
#  'Guerre en Ukraine',
#  'Actions de Vladimir Poutine',
#  'Situation en Ukraine',
#  'Procédure Militaire',
#  'Situation Politique',
#  'Influence sur les Elections',
#  'Candidat Gagnant',
#  'Candidat Perdant',
#  'Réaction du Gagnant',
#  'Réaction de la Maison Blanche',
#  'Objectif du Gagnant',
#  'Tendances des sondages',
#  'Situation Politique',
#  'Problèmes Techniques',
#  'Décisions Politiques',
#  'Régulation',
#  'Critiques',
#  'Situation Politique Actuelle',
#  'Performance de Biden',
#  'Décisions de Biden',
#  'Tendances Electorales',
#  'Comparaison avec Anciens Présidents',
#  'Problemes Economiques',
#  'Personnel Politique',
#  'Entité Politique',
#  'Résultats Electoraux',
#  'Thèmes de Campagne',
#  'Taux de Soutien Electorat',
#  'Objectifs Stratégiques de la France',
#  'Décisions politiques et stratégies',
#  'Menaces extérieures',
#  'Financement des objectifs',
#  'Rencontre du Président et des Entrepreneurs',
#  'Mesures Encouragées par le Gouvernement',
#  "Investissement d'accompagnement du Gouvernement",
#  'Entreprises concernées',
#  'Enjeux environnementaux',
#  'Incitations Complémentaires du Gouvernement',
#  "Conditions de l'Incitation Complémentaire",
#  'Compétition Internationale',
#  'Technologies de réduction des émissions',
#  'Positionnement Stratégique de la France',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Affaires juridiques',
#  'Patrimoine financier',
#  'Acteurs',
#  'Réponses aux charges',
#  'Stratégies Industrielles',
#  'Actions du Gouvernement',
#  'Impact Environnemental',
#  "Conséquences pour l'Entreprise",
#  'Décisions des Entreprises',
#  "Situation Financière de l'Entreprise",
#  'Attitudes des Partenaires Financiers',
#  "Politiques de l'Entreprise",
#  "Engagement Environnemental de l'Entreprise",
#  'Position des Villes',
#  'Efforts de la Chine',
#  "Position de l'Organisation Intergouvernementale",
#  'Conférence sur le Changement Climatique',
#  "Référence de l'Entretien",
#  "Engagement Climatique d'Entreprises",
#  "Recommandations de l'ONU",
#  'Décisions des Entreprises',
#  "Décisions d'Investisseurs",
#  "Critiques d'Antonio Guterres (Secrétaire Général de l’ONU)",
#  "Conférence sur le Climat de l'ONU",
#  'Dérèglement Climatique',
#  "Système d'Information Européen des Feux de Forêts",
#  'Etat des Forêts en France',
#  'Etats Menacés par la Montée des Eaux',
#  'Programme des Nations Unies pour le Développement',
#  'Groupe d’Experts Intergouvernementaux sur l’Evolution du Climat',
#  'Population Menacée par la Montée des Eaux',
#  "Prévisions du Gendarme de l'énergie",
#  "Revenus de l'Etat",
#  "Marché de l'Electricité",
#  'Energies Renouvelables',
#  'Eolien',
#  'Photovoltaïque',
#  'Filière Hydraulique',
#  'Biométhane Injecté',
#  "Politique de l'Etat",
#  'Alliance Internationale',
#  "Objectif de l'Alliance",
#  "Perspective de Remplacement d'Energies",
#  'Modifications législatives',
#  'Soutien financier',
#  'Acteurs politiques',
#  'Initiatives gouvernementales',
#  'Evaluation',
#  'Situation sur le terrain',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Taux de Chômage',
#  "Cours de l'Action de l'Entreprise",
#  'Décisions Gouvernementales',
#  'Stratégie Financière',
#  "Situation Financière de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Rôle du Pharmacien dans le système de Santé',
#  'Les Vaccins administrables par les Pharmaciens',
#  'Prescription Pharmaceutique',
#  'Entretiens pour les Femmes Enceintes',
#  'Importance de la Vaccination',
#  "Performance de l'Entreprise",
#  "Décisions de l'Entreprise",
#  'Problèmes Techniques',
#  'Réponse à des Problèmes Techniques',
#  ...]

# %%
# Send a request to ChatGPT in order to create the dict
content = "["+"".join(x + ", "for x in variables_list)+"]"
res = request_gpt(prompt=REDUCTION_PROMPT, content=content)
variables_dict = json.loads(res.replace("\n", ""))

# %%
# Inversed dict
variables_dict_inversed = {}

for variable, liste in variables_dict.items():
    for e in liste:
        if e not in variables_dict_inversed:
            variables_dict_inversed[e] = [variable]
        else:
            variables_dict_inversed[e].append(variable)
variables_dict_inversed["Indicateur"] = ["Indicateur"]

# %%
# Check if every variable has been mapped
not_mapped = []
for row in df_finance.iterrows():
    _dict = row[1].extraction
    for key, value in _dict.items():
        if key not in variables_dict_inversed:
            print("This key has not been mapped: " + key)
            not_mapped.append(key)

# If not remap
# Lost of information, so try to ask GPT to add to the categories or do it manually
# Need to improve this part
# Out:
# This key has not been mapped: Evénements Climatiques Extrêmes
# This key has not been mapped: Attaques Militaires
# This key has not been mapped: Paroles d'un Responsable Politique
# This key has not been mapped: Image d'Entreprise
# This key has not been mapped: Conséquences d'Entreprise
# This key has not been mapped: Opinions Publiques
# This key has not been mapped: Evènements Politiques
# This key has not been mapped: Evènements Ecologiques
# This key has not been mapped: Production Energétique
# This key has not been mapped: Mouvement Contestataire
# This key has not been mapped: Impact sur la Science
# This key has not been mapped: Situation politique et militaire
# This key has not been mapped: Rôle des civils
# This key has not been mapped: Conséquences du conflit
# This key has not been mapped: Objectifs de la guerre
# This key has not been mapped: Enjeux environnementaux
# This key has not been mapped: Investissements et moyens alloués
# This key has not been mapped: Impacts et conséquences
# This key has not been mapped: Implication Politique
# This key has not been mapped: Santé du Leader
# This key has not been mapped: Perspective d'avenir
# This key has not been mapped: Tensions politiques internationales
# This key has not been mapped: Tendance des Marchés
# This key has not been mapped: Situation géographique
# This key has not been mapped: Conflit
# This key has not been mapped: Manifestants
# This key has not been mapped: Mesures gouvernementales
# This key has not been mapped: Acteurs Internationaux
# This key has not been mapped: Instituts et Organisations
# This key has not been mapped: Intensité des Vagues de Chaleur
# This key has not been mapped: Impact Économique des Vagues de Chaleur
# This key has not been mapped: Relations Entre Syndicats et Direction
# This key has not been mapped: Impact pour les salariés
# This key has not been mapped: Performances de l'Entreprise
# This key has not been mapped: Produits/Services
# This key has not been mapped: Prix de Vente
# This key has not been mapped: Inflation
# This key has not been mapped: Objectifs du Gouvernement
# This key has not been mapped: Dépenses Gouvernementales
# This key has not been mapped: Decisions du Gouvernement
# This key has not been mapped: Reactions Politiques
# This key has not been mapped: Situation Politique et Economique
# This key has not been mapped: Projet de Loi du Gouvernement
# This key has not been mapped: Procédures Administratives
# This key has not been mapped: Communes d'Implantation
# This key has not been mapped: Impacts de la Grève
# This key has not been mapped: Taux de Taxe d'Habitation
# This key has not been mapped: Nombre de Communes Concernées
# This key has not been mapped: Position Géographique des Communes Concernées
# This key has not been mapped: Impact sur les Propriétaires
# This key has not been mapped: Cours de l'action de l'entreprise
# This key has not been mapped: Crise internationale
# This key has not been mapped: Contrat d'Exportation
# This key has not been mapped: Cout de Certification Twitter
# This key has not been mapped: Initiatives d'Elon Musk
# This key has not been mapped: Réactions de Bruno Le Maire
# This key has not been mapped: Sources de Revenus de Twitter
# This key has not been mapped: Position du gouvernement
# This key has not been mapped: Consequences potentielles
# This key has not been mapped: Décisions gouvernementales
# This key has not been mapped: Décisions Judiciaires
# This key has not been mapped: Déclarations
# This key has not been mapped: Spéculation sur la santé du dirigeant
# This key has not been mapped: Mesures de sécurité du dirigeant
# This key has not been mapped: Situation Militaire sur le Terrain
# This key has not been mapped: Infrastructure Affectée
# This key has not been mapped: Acteurs
# This key has not been mapped: Situation Politique Internationale
# This key has not been mapped: Situation Financière des Marchés Mondiaux
# This key has not been mapped: Noms des Scientifiques
# This key has not been mapped: Domaine de Recherche
# This key has not been mapped: Actions Entreprises
# This key has not been mapped: Lieu
# This key has not been mapped: Prochaine Manifestation
# This key has not been mapped: Message
# This key has not been mapped: Tendance Climatique
# This key has not been mapped: Impact sur le Niveau de la Mer
# This key has not been mapped: Impact du Covid-19 sur l'Entreprise
# This key has not been mapped: Inflation
# This key has not been mapped: Auteur de la Désinformation
# This key has not been mapped: Effet sur les Employés
# This key has not been mapped: Situation Politique et Militaire
# This key has not been mapped: Conséquences Civiles
# This key has not been mapped: Réponse Internationale
# This key has not been mapped: Préoccupations Nucléaires
# This key has not been mapped: Transition Gouvernementale
# This key has not been mapped: Plans de gouvernement futur
# This key has not been mapped: Evaluations de transition
# This key has not been mapped: Mécanismes de contrôle
# This key has not been mapped: Enquête Judiciaire
# This key has not been mapped: Situation Internationale
# This key has not been mapped: Relations Économiques Internationales
# This key has not been mapped: Sujets Sensibles
# This key has not been mapped: Situation industrie automobile
# This key has not been mapped: Position des scientifiques
# This key has not been mapped: Arrestation des chercheurs
# This key has not been mapped: Impact environnemental
# This key has not been mapped: Proposition Gouvernementale
# This key has not been mapped: Proposition de Régulation des Salaires
# This key has not been mapped: Personnalités principales
# This key has not been mapped: Position Géopolitique d'Elon Musk
# This key has not been mapped: Impact Emotionnel et Perception Publique
# This key has not been mapped: Financement Réseau Starlink
# This key has not been mapped: Situation Politique internationale
# This key has not been mapped: Visites diplomatiques
# This key has not been mapped: Politique sanitaires
# This key has not been mapped: Coopération internationale
# This key has not been mapped: Zone Géographique Concernée
# This key has not been mapped: Rôle des Incendies
# This key has not been mapped: Stratégie de l'Entreprise
# This key has not been mapped: Future Prévision de la Société
# This key has not been mapped: Investissements Financiers Potentiels
# This key has not been mapped: Analyse Financière
# This key has not been mapped: Aide Financière Internationale
# This key has not been mapped: Stratégie de la Banque Mondiale
# This key has not been mapped: Ambitions de Développement
# This key has not been mapped: Nombre de Candidats LGBTQ
# This key has not been mapped: Rôles Politiques Visés
# This key has not been mapped: Pourcentage De Candidats LGBTQ Démocrates
# This key has not been mapped: Attitudes Politiques Vers Les Droits LGBTQ
# This key has not been mapped: Nouvelle infrastructure
# This key has not been mapped: Localisation
# This key has not been mapped: Tendance
# This key has not been mapped: Infrastructure future
# This key has not been mapped: Investissement gouvernemental
# This key has not been mapped: Secteur bénéficiaire
# This key has not been mapped: Crise sectorielle
# This key has not been mapped: Décisions gouvernementales
# This key has not been mapped: Réponse aux revendications
# This key has not been mapped: Avancements Technologiques
# This key has not been mapped: Investissements et Missions Spatiales
# This key has not been mapped: Objectifs et Résultats de la Mission
# This key has not been mapped: Études et Recherches Planifiées
# This key has not been mapped: Conflit en Ukraine
# This key has not been mapped: Pertes russes
# This key has not been mapped: Préparations russes
# This key has not been mapped: Prévision des attaques russes
# This key has not been mapped: Demandes Politiques
# This key has not been mapped: Presse et perception
# This key has not been mapped: Négociations Commerciales
# This key has not been mapped: Engagements des Gouvernements
# This key has not been mapped: Situation Économique Globale
# This key has not been mapped: Conséquences de Crises Multiples
# This key has not been mapped: Décisions des Gouvernements sur le Climat
# This key has not been mapped: Émissions de Gaz à Effet de Serre
# This key has not been mapped: Décisions Humaines
# This key has not been mapped: Évaluation de la conduite des affaires publiques
# This key has not been mapped: Cote de popularité du principal parti d'opposition
# This key has not been mapped: Politiques Publiques
# This key has not been mapped: Tendances
# This key has not been mapped: Marché Financier
# This key has not been mapped: Risques
# This key has not been mapped: Formation du Gouvernement
# This key has not been mapped: Événements Politiques
# This key has not been mapped: Acteurs du Marché
# This key has not been mapped: Cours de l'action de l'Entreprise
# This key has not been mapped: Tendances du marché
# This key has not been mapped: Autres énergéticiens
# This key has not been mapped: Réactions et Actions Politiques
# This key has not been mapped: Réactions et Perspectives
# This key has not been mapped: Secteur Viticole
# This key has not been mapped: Association pour la reconnaissance des vins bretons
# This key has not been mapped: Production de Vin
# This key has not been mapped: Position de Leader
# This key has not been mapped: Perspective d'avenir
# This key has not been mapped: La charge de travail
# This key has not been mapped: Emploi
# This key has not been mapped: Sens de Commerce
# This key has not been mapped: Réalités Politiques
# This key has not been mapped: Impact Social
# This key has not been mapped: Propriétaire de l'Entreprise
# This key has not been mapped: Développement d'applications santé
# This key has not been mapped: Usage de l'Espace Santé numérique
# This key has not been mapped: Coût des applications
# This key has not been mapped: Influence des réseaux sociaux sur les élections
# This key has not been mapped: Mauvaise pratique de TikTok
# This key has not been mapped: Impact de la désinformation sur le vote
# This key has not been mapped: Résultats de l'étude
# This key has not been mapped: Opinion Publique
# This key has not been mapped: Stabilité Politique
# This key has not been mapped: Actions Gouvernementales
# This key has not been mapped: Discussion entre les Présidents
# This key has not been mapped: Situation du Conflit
# This key has not been mapped: Armes Nucléaires
# This key has not been mapped: Sentiments des Partis d'Opposition
# This key has not been mapped: Démarches de l'Exécutif
# This key has not been mapped: Ventes et Profits
# This key has not been mapped: Public Visé
# This key has not been mapped: Exemptions
# This key has not been mapped: Conséquences Financières pour le Public
# This key has not been mapped: Comparaison des Taux d'Imposition
# This key has not been mapped: Prévisions d'Investissement
# This key has not been mapped: Recettes Prévues
# This key has not been mapped: Endettement Prévu
# This key has not been mapped: Loi Martiale
# This key has not been mapped: Contrôle des Territoires
# This key has not been mapped: Témoignages Locaux
# This key has not been mapped: Action des Troupes Russes
# This key has not been mapped: Propagande des Médias
# This key has not been mapped: Aide Internationale
# This key has not been mapped: Attitude de la Russie
# This key has not been mapped: Position de l'Ukraine
# This key has not been mapped: Engagement des États-Unis
# This key has not been mapped: Bombardements Russes
# This key has not been mapped: Conflit Territoriaire
# This key has not been mapped: Incidents
# This key has not been mapped: Négociations
# This key has not been mapped: Impact
# This key has not been mapped: Déclarations officielles
# This key has not been mapped: Engagements
# This key has not been mapped: Politique Étrangère et Relations Internationales
# This key has not been mapped: Réactions Officielles et Communiqués de Presse
# This key has not been mapped: Situation Géostratégique et Militaire
# This key has not been mapped: Affirmations et Dénis
# This key has not been mapped: Dynamique de Négociation
# This key has not been mapped: Stratégies de Défense
# This key has not been mapped: Efforts Diplomatiques et Négociations
# This key has not been mapped: Situation Sociale Locale
# This key has not been mapped: Situation Environnementale
# This key has not been mapped: Situation des Touristes
# This key has not been mapped: Situation Diplomatique
# This key has not been mapped: Conférence des Nations Unies
# This key has not been mapped: Résolution Climatique
# This key has not been mapped: Accords Environnementaux
# This key has not been mapped: Présence des Chefs d'État et de Gouvernement
# This key has not been mapped: Lieu de l'Événement
# This key has not been mapped: Agenda de l'Événement
# This key has not been mapped: Crises mondiales en cours
# This key has not been mapped: Problèmes environnementaux
# This key has not been mapped: Engagements Écologiques du Gouvernement
# This key has not been mapped: Politique de Lutte Contre le Changement Climatique
# This key has not been mapped: Orientation Ecologique
# This key has not been mapped: Performance du marché
# This key has not been mapped: Analyse du marché
# This key has not been mapped: Tendances technologiques sur le marché
# This key has not been mapped: Opinion/Stratégie d'entreprise
# This key has not been mapped: Réaction des Employés
# This key has not been mapped: Opinion Publique
# This key has not been mapped: Impact sur les Utilisateurs
# This key has not been mapped: Etat de la Désinformation
# This key has not been mapped: Influence des Fake News
# This key has not been mapped: Pratique de l'Entreprise
# This key has not been mapped: Effet des Hackers
# This key has not been mapped: Résultats de l'Expérience
# This key has not been mapped: Opinion de l'Expert
# This key has not been mapped: Transaction Financière
# This key has not been mapped: Acteurs Concernés
# This key has not been mapped: Prévenu Principal
# This key has not been mapped: Position du Chef d'Etat
# This key has not been mapped: Engagement de la France
# This key has not been mapped: Action du Chef d'Etat
# This key has not been mapped: Visions pour les Océans
# This key has not been mapped: Cadre Légal des Océans
# This key has not been mapped: Demande des Députés et Associations
# This key has not been mapped: Proposition à l'Assemblée Nationale
# This key has not been mapped: Politiques Économiques
# This key has not been mapped: Technologies
# This key has not been mapped: Evolution du Rôle de l'Entreprise
# This key has not been mapped: Stratégie de l'Entreprise
# This key has not been mapped: Nouvelles Offres
# This key has not been mapped: Régulation
# This key has not been mapped: Tendances Sectorielles
# This key has not been mapped: Situation Geopolitique
# This key has not been mapped: Actions Militaires
# This key has not been mapped: Tendance
# This key has not been mapped: Situation Politique Internationale
# This key has not been mapped: Décisions des Gouvernements
# This key has not been mapped: Position de l'Entreprise
# This key has not been mapped: Situation Economique Régionale
# This key has not been mapped: Technologies utilisées
# This key has not been mapped: Pression Politique
# This key has not been mapped: Risques d'Entreprise
# This key has not been mapped: Emprunts des Villes
# This key has not been mapped: Actions Climatiques
# This key has not been mapped: Engagements des Banques
# This key has not been mapped: Environnement de l'Entreprise
# This key has not been mapped: Emissions Polluantes
# This key has not been mapped: Position de l'Entreprise/France
# This key has not been mapped: Projet(s) à venir
# This key has not been mapped: Impact sur les Propriétaires
# This key has not been mapped: Comparatif avec d'Autres Villes
# This key has not been mapped: Reaction de l'Elu Local
# This key has not been mapped: Crises qui ont Impacté la Situation
# This key has not been mapped: Objectifs de la Décision
# This key has not been mapped: Prévision d'Investissement pour 2023
# This key has not been mapped: Situation Politique du Président
# This key has not been mapped: Statut de l'Assemblée Nationale
# This key has not been mapped: Image de la France
# This key has not been mapped: Situation du Chef d'Etat
# This key has not been mapped: Stratégie Politique du Président
# This key has not been mapped: Performance du Parti Politique de Renaissance
# This key has not been mapped: Rumeurs Politiques
# This key has not been mapped: Situation Globale
# This key has not been mapped: Impact des Évènements Mondiaux sur l'Entreprise
# This key has not been mapped: Stratégies d'Entreprise
# This key has not been mapped: Performance de l'Entreprise en Afrique
# This key has not been mapped: Défis Futurs
# This key has not been mapped: Élections et Vote
# This key has not been mapped: Impact sur les Relations Internationales
# This key has not been mapped: Stratégie Gouvernementale
# This key has not been mapped: Décisions des Autorités Locales
# This key has not been mapped: Conflit et Sécurité
# This key has not been mapped: Propagande et Journalisme
# This key has not been mapped: Situation sur le Terrain
# This key has not been mapped: Besoin en Financement
# This key has not been mapped: Origine du Financement
# This key has not been mapped: Utilisation du Financement
# This key has not been mapped: Effets Economiques
# This key has not been mapped: Emissions de Gaz de l'Industrie
# This key has not been mapped: Contribution de l'Industrie aux Solutions climatiques
# This key has not been mapped: Émissions de Gaz à Effet de Serre
# This key has not been mapped: Nécessité pour les Entreprises de Participer à l'Effort Climatique
# This key has not been mapped: Réduction des Émissions de Gaz à Effet de Serre par l'Industrie
# This key has not been mapped: Neutralité Carbone de l'Industrie
# This key has not been mapped: Tendance des Émissions de Gaz à Effet de Serre
# This key has not been mapped: Situation Financière des Pays en Développement
# This key has not been mapped: Décisions de l'Entreprise ou du Pays
# This key has not been mapped: Conséquences du Changement Climatique
# This key has not been mapped: Promesses des Pays Riches
# This key has not been mapped: Doctrine économique
# This key has not been mapped: Politiques économiques générales
# This key has not been mapped: Question environnementale
# This key has not been mapped: Problèmes sociaux
# This key has not been mapped: Solution environnementale
# This key has not been mapped: Effet sur l'emploi
# This key has not been mapped: Objectif de croissance
# This key has not been mapped: Vision de la societe
# This key has not been mapped: Déficit Commercial
# This key has not been mapped: Importations
# This key has not been mapped: Exportations
# This key has not been mapped: Inflation
# This key has not been mapped: Prix des biens échangés
# This key has not been mapped: Balance commerciale de l'énergie
# This key has not been mapped: Incident Technique
# This key has not been mapped: Status du Problème
# This key has not been mapped: Affirmation sur la Capacité du Vaisseau
# This key has not been mapped: Ravitaillement
# This key has not been mapped: Expériences à bord
# This key has not been mapped: Actions de l'Autorité
# This key has not been mapped: Comportement des Partis Concernés
# This key has not been mapped: Transparence de l'Entreprise
# This key has not been mapped: Risques Potentiels
# This key has not been mapped: Atout pour la région
# This key has not been mapped: Projet et sa mise en oeuvre
# This key has not been mapped: Impact potentiel sur l'économie maritime
# This key has not been mapped: Évaluation de la situation actuelle
# This key has not been mapped: Fonds de Soutien Militaire aux Ukrainiens
# This key has not been mapped: Situation Politique et Militaire en Ukraine
# This key has not been mapped: Evénements d'Entreprise
# This key has not been mapped: Chiffre d’affaires de l’entreprise
# This key has not been mapped: Contraintes d'entreprise
# This key has not been mapped: Perception Publique
# This key has not been mapped: Transition de Leadership
# This key has not been mapped: Défis de l'Entreprise
# This key has not been mapped: Représentants politiques impliqués
# This key has not been mapped: Tendance du Marché de l'Emploi
# This key has not been mapped: Innovations de l'entreprise
# This key has not been mapped: Situation financière de l'entreprise
# This key has not been mapped: Position de l'entreprise sur le marché
# This key has not been mapped: Prospectives
# This key has not been mapped: Issues d'Election
# This key has not been mapped: Engagement Public
# This key has not been mapped: Guerre en Ukraine
# This key has not been mapped: Actions de Vladimir Poutine
# This key has not been mapped: Situation en Ukraine
# This key has not been mapped: Procédure Militaire
# This key has not been mapped: Influence sur les Elections
# This key has not been mapped: Candidat Gagnant
# This key has not been mapped: Candidat Perdant
# This key has not been mapped: Réaction du Gagnant
# This key has not been mapped: Réaction de la Maison Blanche
# This key has not been mapped: Objectif du Gagnant
# This key has not been mapped: Tendances des sondages
# This key has not been mapped: Problèmes Techniques
# This key has not been mapped: Régulation
# This key has not been mapped: Critiques
# This key has not been mapped: Situation Politique Actuelle
# This key has not been mapped: Performance de Biden
# This key has not been mapped: Décisions de Biden
# This key has not been mapped: Tendances Electorales
# This key has not been mapped: Comparaison avec Anciens Présidents
# This key has not been mapped: Problemes Economiques
# This key has not been mapped: Personnel Politique
# This key has not been mapped: Entité Politique
# This key has not been mapped: Résultats Electoraux
# This key has not been mapped: Thèmes de Campagne
# This key has not been mapped: Taux de Soutien Electorat
# This key has not been mapped: Objectifs Stratégiques de la France
# This key has not been mapped: Décisions politiques et stratégies
# This key has not been mapped: Menaces extérieures
# This key has not been mapped: Financement des objectifs
# This key has not been mapped: Rencontre du Président et des Entrepreneurs
# This key has not been mapped: Mesures Encouragées par le Gouvernement
# This key has not been mapped: Investissement d'accompagnement du Gouvernement
# This key has not been mapped: Entreprises concernées
# This key has not been mapped: Enjeux environnementaux
# This key has not been mapped: Incitations Complémentaires du Gouvernement
# This key has not been mapped: Conditions de l'Incitation Complémentaire
# This key has not been mapped: Compétition Internationale
# This key has not been mapped: Technologies de réduction des émissions
# This key has not been mapped: Positionnement Stratégique de la France
# This key has not been mapped: Affaires juridiques
# This key has not been mapped: Patrimoine financier
# This key has not been mapped: Acteurs
# This key has not been mapped: Réponses aux charges
# This key has not been mapped: Stratégies Industrielles
# This key has not been mapped: Conséquences pour l'Entreprise
# This key has not been mapped: Décisions des Entreprises
# This key has not been mapped: Attitudes des Partenaires Financiers
# This key has not been mapped: Politiques de l'Entreprise
# This key has not been mapped: Engagement Environnemental de l'Entreprise
# This key has not been mapped: Position des Villes
# This key has not been mapped: Efforts de la Chine
# This key has not been mapped: Position de l'Organisation Intergouvernementale
# This key has not been mapped: Conférence sur le Changement Climatique
# This key has not been mapped: Référence de l'Entretien
# This key has not been mapped: Engagement Climatique d'Entreprises
# This key has not been mapped: Recommandations de l'ONU
# This key has not been mapped: Décisions des Entreprises
# This key has not been mapped: Décisions d'Investisseurs
# This key has not been mapped: Critiques d'Antonio Guterres (Secrétaire Général de l’ONU)
# This key has not been mapped: Conférence sur le Climat de l'ONU
# This key has not been mapped: Dérèglement Climatique
# This key has not been mapped: Système d'Information Européen des Feux de Forêts
# This key has not been mapped: Etat des Forêts en France
# This key has not been mapped: Etats Menacés par la Montée des Eaux
# This key has not been mapped: Programme des Nations Unies pour le Développement
# This key has not been mapped: Groupe d’Experts Intergouvernementaux sur l’Evolution du Climat
# This key has not been mapped: Population Menacée par la Montée des Eaux
# This key has not been mapped: Prévisions du Gendarme de l'énergie
# This key has not been mapped: Revenus de l'Etat
# This key has not been mapped: Marché de l'Electricité
# This key has not been mapped: Eolien
# This key has not been mapped: Photovoltaïque
# This key has not been mapped: Filière Hydraulique
# This key has not been mapped: Biométhane Injecté
# This key has not been mapped: Politique de l'Etat
# This key has not been mapped: Alliance Internationale
# This key has not been mapped: Objectif de l'Alliance
# This key has not been mapped: Perspective de Remplacement d'Energies
# This key has not been mapped: Modifications législatives
# This key has not been mapped: Soutien financier
# This key has not been mapped: Acteurs politiques
# This key has not been mapped: Initiatives gouvernementales
# This key has not been mapped: Evaluation
# This key has not been mapped: Situation sur le terrain
# This key has not been mapped: Stratégie Financière
# This key has not been mapped: Rôle du Pharmacien dans le système de Santé
# This key has not been mapped: Les Vaccins administrables par les Pharmaciens
# This key has not been mapped: Prescription Pharmaceutique
# This key has not been mapped: Entretiens pour les Femmes Enceintes
# This key has not been mapped: Importance de la Vaccination
# This key has not been mapped: Problèmes Techniques
# This key has not been mapped: Réponse à des Problèmes Techniques
# This key has not been mapped: Partenariats et Collaborations
# This key has not been mapped: Futurs Projets
# This key has not been mapped: Gestion des Déchets
# This key has not been mapped: Innovation Technologique
# This key has not been mapped: Perspectives de l'Entreprise
# This key has not been mapped: Impact Sociétal
# This key has not been mapped: Partenaires de l'Entreprise
# This key has not been mapped: Audience de l'Entreprise
# This key has not been mapped: Fonction de l'Innovation
# This key has not been mapped: Objectifs de l'Innovation
# This key has not been mapped: Opportunités Immobilières
# This key has not been mapped: Loi Climat
# This key has not been mapped: Rénovations Energétiques
# This key has not been mapped: Performance Energétique des Logements
# This key has not been mapped: Stratégie de Vente
# This key has not been mapped: Projet d'énergie renouvelable
# This key has not been mapped: Loi sur l'énergie
# This key has not been mapped: Ethique de l'entreprise
# This key has not been mapped: Activité de l'entreprise
# This key has not been mapped: Attractivité de l'entreprise
# This key has not been mapped: Evolution du Salon
# This key has not been mapped: Situation Economique Générale
# This key has not been mapped: Perspectives Economiques
# This key has not been mapped: Effets Environnementaux
# This key has not been mapped: Niveau de Risque
# This key has not been mapped: Conséquences sur le Secteur Agricole
# This key has not been mapped: Régions Affectées
# This key has not been mapped: Impact sur la Production
# This key has not been mapped: Stratégie et décisions militaires
# This key has not been mapped: Situation géopolitique
# This key has not been mapped: Droits humains et valeurs défendus
# This key has not been mapped: Impact du Conflit sur la Population
# This key has not been mapped: Réaction de la Population
# This key has not been mapped: État Psychologique de la Population
# This key has not been mapped: Acteurs Externes
# This key has not been mapped: Nouvelles Offres de Services
# This key has not been mapped: Décisions Administratives
# This key has not been mapped: Réaction des Parties Prenantes
# This key has not been mapped: Économies Réalisées
# This key has not been mapped: Budget de l'État
# This key has not been mapped: Vote de l'Assemblée
# This key has not been mapped: Attitude du Gouvernement
# This key has not been mapped: Réactions de l'Opposition
# This key has not been mapped: Position du Parti Politique
# This key has not been mapped: Informations Fuitées
# This key has not been mapped: Réponse de l'Élysée
# This key has not been mapped: Ambiance Interne au Parti
# This key has not been mapped: Intervention de la Première Ministre
# This key has not been mapped: Position de la Première Ministre sur le Dividende Salarié
# This key has not been mapped: Tendances Générales
# This key has not been mapped: Surpopulation et Climat
# This key has not been mapped: Ressources Mondiales
# This key has not been mapped: Politique de Population
# This key has not been mapped: Réchauffement Climatique et Richesse
# This key has not been mapped: Impact du niveau de vie sur Pollution
# This key has not been mapped: Développements Climatiques
# This key has not been mapped: Activité de Pêche
# This key has not been mapped: Modele Numérique
# This key has not been mapped: Stocks de Poissons
# This key has not been mapped: Politiques de Pêche
# This key has not been mapped: Nombre de Volailles Abattues
# This key has not been mapped: Cause
# This key has not been mapped: Conséquences pour les Elevages
# This key has not been mapped: Conséquences pour le Marché
# This key has not been mapped: Réaction des Syndicats
# This key has not been mapped: Situation Financière de la filiale
# This key has not been mapped: Décisions de la filiale
# This key has not been mapped: Lois et Régulations
# This key has not been mapped: Stratégie d’Entreprise de SNCF Gares & Connexions
# This key has not been mapped: Parties Prenantes
# This key has not been mapped: Lieu
# This key has not been mapped: Stratégies et Technologies Écologiques
# This key has not been mapped: Défis Environnementaux
# This key has not been mapped: Evenement
# This key has not been mapped: Projections de marché
# This key has not been mapped: Cours de l'Action
# This key has not been mapped: Role de la France dans le Dérèglement Climatique
# This key has not been mapped: Emissions de CO2 de la France
# This key has not been mapped: Empreinte Carbone Globale de la France
# This key has not been mapped: Objectifs Internationaux
# This key has not been mapped: Publications sur les Réseaux Sociaux
# This key has not been mapped: Réactions à l'Emission de CO2
# This key has not been mapped: Effets Réglementaires et Financiers
# This key has not been mapped: Lobbyistes d'Entreprises
# This key has not been mapped: Nombre de Participants à la Conférence
# This key has not been mapped: Nombre Observateurs Accrédités
# This key has not been mapped: Entreprises des Énergies Fossiles
# This key has not been mapped: Influence des Énergies Fossiles
# This key has not been mapped: Pays les Plus Touchés par le Climat
# This key has not been mapped: Organisation de Surveillance
# This key has not been mapped: Banques Investissant dans les Énergies Fossiles
# This key has not been mapped: Niveau de Risque
# This key has not been mapped: Décisions des Autorités
# This key has not been mapped: Régions Affectées
# This key has not been mapped: Impact sur la Production
# This key has not been mapped: Marques d'Entreprise
# This key has not been mapped: Éthique de l'Entreprise
# This key has not been mapped: Opportunités de Recrutement
# This key has not been mapped: Candidatures à l'Emploi
# This key has not been mapped: Tendance de l'Emploi
# This key has not been mapped: Impact de la Production Locale
# This key has not been mapped: Réglementations
# This key has not been mapped: Opinions
# This key has not been mapped: Relations Entreprise-Gouvernement
# This key has not been mapped: Accusations Juridiques
# This key has not been mapped: Acteurs concernés
# This key has not been mapped: Coût de l'Énergie
# This key has not been mapped: Production
# This key has not been mapped: Perspectives Future
# This key has not been mapped: Acteurs
# This key has not been mapped: Région
# This key has not been mapped: Nomination à la Tête de l'Entreprise
# This key has not been mapped: Position de l'Entreprise
# This key has not been mapped: Défis de l'Entreprise
# This key has not been mapped: Sentiment du Rapporteur de la Commission
# This key has not been mapped: Projet de Construction
# This key has not been mapped: Impact Économique Régional
# This key has not been mapped: Perspectives de Croissance
# This key has not been mapped: Lancement de la fusée
# This key has not been mapped: Société lancement fusée
# This key has not been mapped: Cause du report
# This key has not been mapped: Décisions de la Société
# This key has not been mapped: Reprogrammation du lancement
# This key has not been mapped: alternatives de lancement
# This key has not been mapped: Niveau de Participation à la Grève
# This key has not been mapped: Mobilisation par rapport à une Précédente Journée d'Action
# This key has not been mapped: Impact de la Grève sur les Transports
# This key has not been mapped: Comparaison avec d'autres Grèves
# This key has not been mapped: Impact sur le Trafic en Ile-de-France
# This key has not been mapped: Méthodes d'Adaptation des Salariés
# This key has not been mapped: Impact Continu de la Grève
# This key has not been mapped: Taux de Participation à la Grève
# This key has not been mapped: Manifestations
# This key has not been mapped: Impact sur les Transports
# This key has not been mapped: Conditions de travail
# This key has not been mapped: Représentant de l'Entreprise
# This key has not been mapped: Situation Légale de l'Entreprise
# This key has not been mapped: Formation de l'Entreprise
# This key has not been mapped: Contribution de la Chine à la réduction des émissions mondiales de carbone
# This key has not been mapped: Rôle de la Chine dans les technologies d'énergie propre
# This key has not been mapped: Crise énergétique mondiale
# This key has not been mapped: Impact de l'utilisation de combustibles fossiles sur les émissions de carbone
# This key has not been mapped: Position Politique de Xi Jinping
# This key has not been mapped: Mandat de Xi Jinping
# This key has not been mapped: Événements Politiques
# This key has not been mapped: Date d'Événements
# This key has not been mapped: Lieu d'Événements
# This key has not been mapped: Autres Rencontres Programmées
# This key has not been mapped: Réconduction de Xi Jinping
# This key has not been mapped: Emissions de CO2
# This key has not been mapped: Conséquences pour le Climat
# This key has not been mapped: Facteurs Attribués
# This key has not been mapped: Trajet de l'Emission
# This key has not been mapped: Utilisation du Pétrole et du Charbon
# This key has not been mapped: Situation Sanitaire des Volailles
# This key has not been mapped: Décisions des Autorités
# This key has not been mapped: Production Régionale de Volailles
# This key has not been mapped: Impact sur l'Industrie Agricole
# This key has not been mapped: Réactions du Monde Agricole
# This key has not been mapped: Contributions à la Réduction des Émissions de Carbone
# This key has not been mapped: Rôle dans les Technologies d'Énergie Propre
# This key has not been mapped: Situation Énergétique Mondiale
# This key has not been mapped: Utilisation de Combustibles Fossiles
# This key has not been mapped: Augmentation des Émissions de Carbone
# This key has not been mapped: Cours de l'action de l'entreprise
# This key has not been mapped: Impact du Changement Climatique
# This key has not been mapped: Efforts de Lutte contre le Changement Climatique
# This key has not been mapped: Populations Affectées
# This key has not been mapped: Zones Géographiques Affectées
# This key has not been mapped: Organisateurs d'Événements
# This key has not been mapped: Chefs d'État et de Gouvernement
# This key has not been mapped: Négociations
# This key has not been mapped: Déclaration Antérieure
# This key has not been mapped: Innovation et Transformation
# This key has not been mapped: Risques identifiés
# This key has not been mapped: Industrie
# This key has not been mapped: Politiques et Règlementations
# This key has not been mapped: Image de l'Entreprise
# This key has not been mapped: Agences de régulation
# This key has not been mapped: Règles et régulations
# This key has not been mapped: Informations Juridiques sur l'Entreprise
# This key has not been mapped: Cours de l'action de l'Entreprise
# This key has not been mapped: Négociations
# This key has not been mapped: Grève
# This key has not been mapped: Concurrence de l'Entreprise
# This key has not been mapped: Stratégie de l'Entreprise
# This key has not been mapped: Partenariats de l'Entreprise
# This key has not been mapped: Produits de l'Entreprise
# This key has not been mapped: Initiatives Sociales de l'Entreprise
# This key has not been mapped: Situation Diplomatique
# This key has not been mapped: Stratégies Militaires
# This key has not been mapped: Objectifs Stratégiques
# This key has not been mapped: Technologies Militaires
# This key has not been mapped: Situation géopolitique
# This key has not been mapped: Position des parties
# This key has not been mapped: Zones de Conflit
# This key has not been mapped: Acteurs impliqués
# This key has not been mapped: Incidents Militaires
# This key has not been mapped: Impact sur l'infrastructure
# This key has not been mapped: Conséquences humaines
# This key has not been mapped: Forces Militaires
# This key has not been mapped: Enjeux Géopolitiques
# This key has not been mapped: Tendance
# This key has not been mapped: Action en Justice
# This key has not been mapped: Personnes Impliquées
# This key has not been mapped: Documents Saisis
# This key has not been mapped: Enquête
# This key has not been mapped: Situation Financière de l'Implication
# This key has not been mapped: Mesures Législatives
# This key has not been mapped: Stance Politique
# This key has not been mapped: Contexte politique
# This key has not been mapped: Situation financière du pays
# This key has not been mapped: Décisions gouvernementales
# This key has not been mapped: Opinions politiques et économiques
# This key has not been mapped: Réactions de l'Opposition
# This key has not been mapped: Implications Économiques
# This key has not been mapped: Impact sur les Investisseurs
# This key has not been mapped: Commentaires de Personnes Clés
# This key has not been mapped: Effet sur les Entreprises
# This key has not been mapped: Perspectives du Déficit Public
# This key has not been mapped: Préoccupations Environnementales
# This key has not been mapped: Inégalités Sociales
# This key has not been mapped: Attitude Sociétale
# This key has not been mapped: Réactions des Employés
# This key has not been mapped: Opinion Publique
# This key has not been mapped: Secteurs Concernés
# This key has not been mapped: Actions Syndicales
# This key has not been mapped: Répercussions Environnementales
# This key has not been mapped: Implication d’Organisations Externes
# This key has not been mapped: Impact sur les Consommateurs et l'Opinion Publique
# This key has not been mapped: Gestion de la Marque et de la Réputation
# This key has not been mapped: Négociations Syndicales
# This key has not been mapped: Mouvement de Grève
# This key has not been mapped: Innovation Technologique
# This key has not been mapped: Amélioration de l'Efficacité
# This key has not been mapped: Essais et Développement
# This key has not been mapped: Conséquences de l'accident
# This key has not been mapped: Causes de l'accident
# This key has not been mapped: Représentant de l'entreprise
# This key has not been mapped: Impact sur les Éleveurs
# This key has not been mapped: Impact sur le Prix des Œufs
# This key has not been mapped: Position du Président Français
# This key has not been mapped: Réaction du Régime Iranien
# This key has not been mapped: Situation en Iran
# This key has not been mapped: Position à l'égard de l'Iran
# This key has not been mapped: Accord sur le Nucléaire
# This key has not been mapped: Position du Gouvernement Russe
# This key has not been mapped: Demande d'Ukraine
# This key has not been mapped: Position du Président Russe
# This key has not been mapped: Déclaration du Vice-ministre Russe des Affaires étrangères
# This key has not been mapped: Position Ministère de la défense Russe
# This key has not been mapped: Demande Répétée d'Ukraine
# This key has not been mapped: Avancées militaires ukrainiennes
# This key has not been mapped: Actions du Parti des Travailleurs
# This key has not been mapped: Décisions de Bolsonaro
# This key has not been mapped: Accusations contre Bolsonaro
# This key has not been mapped: Conséquences potentielles pour Bolsonaro
# This key has not been mapped: Responsabilité de l'enquête
# This key has not been mapped: Futur enquêteur probable
# This key has not been mapped: Position de Raul Araújo
# This key has not been mapped: Plainte principale du PT
# This key has not been mapped: Situation Politique de l'Iran
# This key has not been mapped: Politique Diplomatique de la France
# This key has not been mapped: Rôle et Actions du Président Français
# This key has not been mapped: Impact des Sanctions
# This key has not been mapped: Activité Économique
# This key has not been mapped: Situation Globale
# This key has not been mapped: Impact sur le Coût de Vie
# This key has not been mapped: Performances de Stock
# This key has not been mapped: Politique Américaine
# This key has not been mapped: Question de Taïwan
# This key has not been mapped: Question de l'arme Nucléaire en Ukraine
# This key has not been mapped: Relations Chine - Etat-Unis
# This key has not been mapped: Problème de la Corée du Nord
# This key has not been mapped: Sanctions Politiques
# This key has not been mapped: Décisions du Gouvernement Canadien
# This key has not been mapped: Nombre de Sanctionnés
# This key has not been mapped: Réactions Politiques
# This key has not been mapped: Nombre de réfugiés
# This key has not been mapped: Budget total
# This key has not been mapped: Projection budgétaire
# This key has not been mapped: Dépenses d’hébergement
# This key has not been mapped: Allocation pour demandeur d'asile
# This key has not been mapped: Coût de l'accompagnement social
# This key has not been mapped: Financement supplémentaire
# This key has not been mapped: Croissance Démographique
# This key has not been mapped: Pressions Environnementales
# This key has not been mapped: Développement Économique
# This key has not been mapped: Situation Financière des Pays Vulnérables
# This key has not been mapped: Décisions de l'Organisation
# This key has not been mapped: Financements et Contributions
# This key has not been mapped: Pays Bénéficiaires
# This key has not been mapped: Opposition et Critiques
# This key has not been mapped: Cause du Dérèglement Climatique
# This key has not been mapped: Niveau de CO2
# This key has not been mapped: Impact du Dérèglement Climatique
# This key has not been mapped: Effort pour la Cause Climatique
# This key has not been mapped: Mesure du Changement Climatique
# This key has not been mapped: Incident Sismique
# This key has not been mapped: Réponse d'urgence
# This key has not been mapped: Situation des infrastructures
# This key has not been mapped: Sécurité Civile
# This key has not been mapped: Environmental Impact
# This key has not been mapped: Candidat et Parti Politique
# This key has not been mapped: Poste Visé
# This key has not been mapped: Opposition à Candidature
# This key has not been mapped: Situation Politique Actuelle
# This key has not been mapped: Performances Passées
# This key has not been mapped: Situation Géopolitique et Sécuritaire
# This key has not been mapped: Actions de l'OTAN
# This key has not been mapped: Réaction du Gouvernement Polonais
# This key has not been mapped: Articles du traité de Washington
# This key has not been mapped: Pays
# This key has not been mapped: Décisions des Leaders Politiques
# This key has not been mapped: Institutions
# This key has not been mapped: Situation Politique et Géopolitique
# This key has not been mapped: Décisions Stratégiques de l'État
# This key has not been mapped: Réactions Internationales
# This key has not been mapped: Possibilités de Résolution
# This key has not been mapped: Situation Financière de la Ville
# This key has not been mapped: Réaction du Public
# This key has not been mapped: Conditions d'Application de la Taxe
# This key has not been mapped: Infrastructure et Services Publics
# This key has not been mapped: Actions Gouvernementales
# This key has not been mapped: Situation Militaire
# This key has not been mapped: Incident international
# This key has not been mapped: Intervenants
# This key has not been mapped: Réponses politiques
# This key has not been mapped: Tensions Internationales
# This key has not been mapped: Actions de la Russie
# This key has not been mapped: Position de l'Ukraine
# This key has not been mapped: Tension Géopolitique
# This key has not been mapped: Performances des Marchés Boursiers
# This key has not been mapped: Attente des Marchés
# This key has not been mapped: Déroulement de la Guerre
# This key has not been mapped: Actions du Dirigeant
# This key has not been mapped: Situation Politique Internationale
# This key has not been mapped: Décisions Internationales
# This key has not been mapped: Situation Militaire
# This key has not been mapped: Plan Climatique des Pays Développés
# This key has not been mapped: Situation des Pays Vulnérables
# This key has not been mapped: Objectif de Limitation du Réchauffement
# This key has not been mapped: Position de l'Arabie saoudite et de la Chine
# This key has not been mapped: Attitude des Pays Développés face au Changement Climatique
# This key has not been mapped: Attentes de la COP27
# This key has not been mapped: Position de l'UE
# This key has not been mapped: Evolution des ventes
# This key has not been mapped: Cours des indices
# This key has not been mapped: Décisions des autorités
# This key has not been mapped: Volume de ventes
# This key has not been mapped: Position gouvernementale
# This key has not been mapped: Situation Ecologique
# This key has not been mapped: Subventions et Fonds Publics
# This key has not been mapped: Prise de position sur le Climat
# This key has not been mapped: Exportation
# This key has not been mapped: Influence Extérieure
# This key has not been mapped: Rapport d'Activité
# This key has not been mapped: Organisations Non Gouvernementales
# This key has not been mapped: Emplacement de Production
# This key has not been mapped: Fabricants
# This key has not been mapped: Produits
# This key has not been mapped: Emplacement du Fabricant
# This key has not been mapped: Source des Matériaux
# This key has not been mapped: Procédure de Production
# This key has not been mapped: Réactions du Public
# This key has not been mapped: Exceptions à la Décision de l'Entreprise
# This key has not been mapped: Taux de vaccination
# This key has not been mapped: Campagne de vaccination
# This key has not been mapped: Vaccins disponibles
# This key has not been mapped: Recommandations de santé publique
# This key has not been mapped: Tendance de la pandémie
# This key has not been mapped: Situation du Marché des Oeufs
# This key has not been mapped: Situation Sanitaire des Elevages
# This key has not been mapped: Préoccupations des Professionnels
# This key has not been mapped: Initiative gouvernementale
# This key has not been mapped: Cibles de l'initiative
# This key has not been mapped: Impact sur l'environnement
# This key has not been mapped: Fondement juridique
# This key has not been mapped: Objectif de l'initiative
# This key has not been mapped: Relation avec la Justice
# This key has not been mapped: Directeurs d'entreprise
# This key has not been mapped: Localisation
# This key has not been mapped: Opinion Publique
# This key has not been mapped: Tendance de l'épidémie du COVID-19
# This key has not been mapped: Décisions du gouvernement
# This key has not been mapped: Efficacité de la mesure anti-covid
# This key has not been mapped: Statistiques COVID-19
# This key has not been mapped: Informations erronées sur COVID-19
# This key has not been mapped: Actionnaires de l'Entreprise
# This key has not been mapped: Image de l'Entreprise
# This key has not been mapped: Prise de décision de l'Entreprise
# This key has not been mapped: Gestion des conflits de l'Entreprise
# This key has not been mapped: Comportement de l'animatueur de l'Entreprise
# This key has not been mapped: Public de l'Entreprise
# This key has not been mapped: Stratégie d'Économie d'Énergie
# ...
# This key has not been mapped: Critique de Lula
# This key has not been mapped: Catastrophes Naturelles
# This key has not been mapped: Effets Climatiques
# This key has not been mapped: Impact sur la Population
# This key has not been mapped: Impact sur l'Économie
# This key has not been mapped: Recherche Scientifique
# This key has not been mapped: Présence de l'Entreprise en Afrique
# This key has not been mapped: Rôles Internes de l'Entreprise
# This key has not been mapped: Controverses de l'Entreprise
# This key has not been mapped: Prévalence du Cancer
# This key has not been mapped: Traitement du Cancer
# This key has not been mapped: Effets secondaires du Traitement
# This key has not been mapped: Coût du traitement du Cancer
# This key has not been mapped: Dynamique du Marché
# This key has not been mapped: Futurs Projets
# This key has not been mapped: Incidents Techniques
# This key has not been mapped: Rivalité sur le Marché
# This key has not been mapped: Effets du Changement Climatique
# This key has not been mapped: Méthodes d'Observation du Changement Climatique
# This key has not been mapped: Variabilités Temporelles du Climat
# This key has not been mapped: Programme de la Communauté des Climatologues
# This key has not been mapped: Historique des Données Climatiques en Polynésie française
# This key has not been mapped: Traitement des Données Climatiques
# This key has not been mapped: Objectif de l'Analyse des Données
# This key has not been mapped: Politique Étrangère du Président
# This key has not been mapped: Décisions et Position de l'Arabie Saoudite
# This key has not been mapped: Influence sur les Marchés du Pétrole
# This key has not been mapped: Intervenants
# This key has not been mapped: Conséquences sur la Population
# This key has not been mapped: Dommages Matériels
# This key has not been mapped: Sécurité et conflits
# This key has not been mapped: Intervenants
# This key has not been mapped: Mesures prises
# This key has not been mapped: Conflit
# This key has not been mapped: Situation Politique et Diplomatique
# This key has not been mapped: Relation Diplomatique et Coopération
# This key has not been mapped: Reconnaissance Internationale
# This key has not been mapped: Importance de l'Événement
# This key has not been mapped: Rémunération des employés de l'entreprise
# This key has not been mapped: Tendance du marché du carburant
# This key has not been mapped: Activité de l'entreprise
# This key has not been mapped: Action gouvernementale
# This key has not been mapped: Politique Environnementale du Gouvernement
# This key has not been mapped: Réactions du Public
# This key has not been mapped: Pratiques de Consommation Énergétique
# This key has not been mapped: Consommation Énergétique Critiquée
# This key has not been mapped: Population de Crabes des Neiges
# This key has not been mapped: Décisions de l'Administration
# This key has not been mapped: Hypothèses des Scientifiques
# This key has not been mapped: Conditions environnementales
# This key has not been mapped: Etat d'Infrastructure
# This key has not been mapped: Action d'Urgence
# This key has not been mapped: Situation Immobilière
# This key has not been mapped: Calamité Régionale
# This key has not been mapped: Politiques Nationales
# This key has not been mapped: Déclarations des Responsables
# This key has not been mapped: Perspectives du Secteur Énergétique
# This key has not been mapped: Gouvernance Internationale
# This key has not been mapped: Situation du Réseau de Transport
# This key has not been mapped: Grève
# This key has not been mapped: Manque de Personnel
# This key has not been mapped: Futur
# This key has not been mapped: Situation Ecologique
# This key has not been mapped: Consequences Economiques
# This key has not been mapped: Situation Socio-économique
# This key has not been mapped: Secteurs Affectés
# This key has not been mapped: Effets Potentiels
# This key has not been mapped: Interventions du Gouvernement
# This key has not been mapped: Réponses des Travailleurs
# This key has not been mapped: Appel à la Grève
# This key has not been mapped: Raisons de la Grève
# This key has not been mapped: Pénuries
# This key has not been mapped: Manifestations
# This key has not been mapped: Perturbations
# This key has not been mapped: Prédiction de Crises
# This key has not been mapped: Événements Prédits
# This key has not been mapped: Effets Psychologiques Prévus
# This key has not been mapped: Durée de l'Événement Prévu
# This key has not been mapped: Mois Significatifs Prédits
# This key has not been mapped: Décision à prendre
# This key has not been mapped: Opération militaire
# This key has not been mapped: Administration Trump
# This key has not been mapped: CDC
# This key has not been mapped: Impact sur la Population
# This key has not been mapped: Variant du Coronavirus
# This key has not been mapped: Tendances Militaires
# This key has not been mapped: Conséquences Militaires
# This key has not been mapped: Technologies Militaires
# This key has not been mapped: Réactions Internationales
# This key has not been mapped: Décisions de l'Entreprise/Gouvernement
# This key has not been mapped: Indicateurs Economiques
# This key has not been mapped: Infrastructure Publique
# This key has not been mapped: Villes Affectées
# This key has not been mapped: Dégâts Matériels
# This key has not been mapped: Industries Affectées
# This key has not been mapped: Qualité de Récolte
# This key has not been mapped: État du Marché
# This key has not been mapped: Facteur d'Impact
# This key has not been mapped: Stratégie de l'Entreprise
# This key has not been mapped: Historique de la Production
# This key has not been mapped: Perspective d'Avenir
# This key has not been mapped: Commentaire d'Expert
# This key has not been mapped: Projet d'Investissement de l'Entreprise
# This key has not been mapped: Réaction des Autorités
# This key has not been mapped: Réponse de l'Opinion Publique
# This key has not been mapped: Accusations Juridiques et Enjeux
# This key has not been mapped: Politique Énergétique de l'Allemagne
# This key has not been mapped: État des Négociations Politiques
# This key has not been mapped: Considérations Économiques et Énergétiques
# This key has not been mapped: Stratégies pour l'Effet de Serre
# This key has not been mapped: Réglementations et Politiques
# This key has not been mapped: Impact du Marché
# This key has not been mapped: Situation Financière des Entreprises Pétrolières
# This key has not been mapped: Mouvements Sociaux
# This key has not been mapped: Stocks Stratégiques de Carburant
# This key has not been mapped: Contributions des Opérateurs
# This key has not been mapped: Volume de Smartphones Jetés
# This key has not been mapped: Recyclage de Minerais Rares
# This key has not been mapped: Prise de Conscience de la Population
# This key has not been mapped: Volume Global de Téléphones Portables
# This key has not been mapped: Téléphones Non Utilisés en Europe
# This key has not been mapped: Volume Annuel de Déchets Électroniques dans le Monde
# This key has not been mapped: Prévision de Déchets Électroniques en 2030
# This key has not been mapped: Recyclage des Déchets Électroniques dans le Monde
# This key has not been mapped: Objectif de Recyclage en 2023 par l’Union Internationale des Télécommunications
# This key has not been mapped: Dispositifs de Recyclage
# This key has not been mapped: Performance Boursière de l'Entreprise
# This key has not been mapped: Politiques de l'Administration
# This key has not been mapped: Opinion Publique
# This key has not been mapped: Projections futures
# This key has not been mapped: Nouveaux Résultats de Recherche
# This key has not been mapped: Méthodologie de Recherche
# This key has not been mapped: Estimations
# This key has not been mapped: Effets Observés
# This key has not been mapped: Comparaison avec la Moyenne Globale
# This key has not been mapped: Indices Boursiers
# This key has not been mapped: Conflicts
# This key has not been mapped: Réactions des Parties Prenantes
# This key has not been mapped: Politique Environnementale de l'Entreprise
# This key has not been mapped: Marché des Téléphones
# This key has not been mapped: Déchets Électroniques
# This key has not been mapped: Recyclage
# This key has not been mapped: Ressources Précieuses
# This key has not been mapped: Solutions Proposées
# This key has not been mapped: Loi de Moore
# This key has not been mapped: Prédictions sur la Loi de Moore
# This key has not been mapped: Rôle de la Loi de Moore
# This key has not been mapped: Acteurs
# This key has not been mapped: Evolution Technologique
# This key has not been mapped: Demande sur le Marché des Semi-Conducteurs
# This key has not been mapped: Effets sur l'Économie
# This key has not been mapped: Prévisions Scientifiques
# This key has not been mapped: Efforts pour atténuer le Changement Climatique
# This key has not been mapped: Taux d'Activité
# This key has not been mapped: Incidents Majeurs
# This key has not been mapped: Perspective
# This key has not been mapped: Situation Economique Générale
# This key has not been mapped: Position Diplomatique de la Chine
# This key has not been mapped: Mesures Coercitives Unilatérales
# This key has not been mapped: Décisions des Nations Unies
# This key has not been mapped: Budget 2023
# This key has not been mapped: Niveau d'émissions de gaz à effet de serre
# This key has not been mapped: Prédictions de température
# This key has not been mapped: Utilisation d'énergies fossiles
# This key has not been mapped: Température moyenne planétaire
# This key has not been mapped: Réchauffement de l'ensemble de la Terre
# This key has not been mapped: Situation sociale et politique
# This key has not been mapped: Mouvements syndicaux
# This key has not been mapped: Décisions gouvernementales
# This key has not been mapped: Date de l'Annonce
# This key has not been mapped: Prochaine Date du Conseil
# This key has not been mapped: Réunion Prévue initialement
# This key has not been mapped: Lieu de la Réunion
# This key has not been mapped: Acteurs impliqués
# This key has not been mapped: Raison du report
# This key has not been mapped: Sujets de dissension
# This key has not been mapped: Evolution Climatique
# This key has not been mapped: Risques Potentiels
# This key has not been mapped: Effets Écosystémiques
# This key has not been mapped: Recherches Scientifiques
# This key has not been mapped: Opérations de Prélèvement
# This key has not been mapped: Evolution Climatique
# This key has not been mapped: Localisation Géographique
# This key has not been mapped: Recherche Scientifique
# This key has not been mapped: Conséquences Environnementales
# This key has not been mapped: Conséquences sur les Organismes Vivants
# This key has not been mapped: Situation Politique de l'Italie
# This key has not been mapped: Attitude de Macron
# This key has not been mapped: Relations entre Paris et Rome
# This key has not been mapped: Attitude de Meloni
# This key has not been mapped: Action Gouvernementale
# This key has not been mapped: Influence sur la Population
# This key has not been mapped: Position des Partis
# This key has not been mapped: Position du Président
# This key has not been mapped: Actions de l'ONG Sant'Egidio
# This key has not been mapped: Points de Vue Externes
# This key has not been mapped: Représentation des Femmes au Pouvoir
# This key has not been mapped: Rôle des Femmes
# This key has not been mapped: Changements Récents
# This key has not been mapped: Contexte
# This key has not been mapped: Situation Géopolitique et Économique
# This key has not been mapped: Transition Climatique
# This key has not been mapped: Métaux Stratégiques
# This key has not been mapped: Industrie et Économie
# This key has not been mapped: Rapport du Cabinet McKinsey
# This key has not been mapped: Objectif de Neutralité Carbone
# This key has not been mapped: Tendance Energétique
# This key has not been mapped: Initiative de l'Entreprise
# This key has not been mapped: Trafic
# This key has not been mapped: Activités de Protestation
# This key has not been mapped: Attitude envers les vols privés
# This key has not been mapped: Volume de Passagers
# This key has not been mapped: Clientèle de l'entreprise
# This key has not been mapped: Cours et Indices Boursiers
# This key has not been mapped: Réglementation
# This key has not been mapped: Stratégie d'Investissement
# This key has not been mapped: Tendances de l'Innovation
# This key has not been mapped: Enjeux Environnementaux
# This key has not been mapped: Enjeux Sociaux
# This key has not been mapped: Situation Financière de l'Apiculture
# This key has not been mapped: Décisions des Apiculteurs
# This key has not been mapped: Environnement de l'Apiculture
# This key has not been mapped: Destruction des Ruches
# This key has not been mapped: Retard du Projet
# This key has not been mapped: Conséquences du Retard
# This key has not been mapped: Alternatives
# This key has not been mapped: Filière Spatiale Européenne
# This key has not been mapped: Partenariats Abandonnés
# This key has not been mapped: Projet de l'Entreprise
# This key has not been mapped: Environnement
# This key has not been mapped: Conflit Potentiel
# This key has not been mapped: Réseau de Blanchiment
# This key has not been mapped: Montant Blanchi
# This key has not been mapped: Nature de la Fraude
# This key has not been mapped: Opérations Illégales
# This key has not been mapped: Destination des Fonds
# This key has not been mapped: Fonds Saisis
# This key has not been mapped: Acteur Principal du Réseau
# This key has not been mapped: Actions Judiciaires
# This key has not been mapped: Initiatives Gouvernementales
# This key has not been mapped: Opinion publique
# This key has not been mapped: Caractéristique du produit
# This key has not been mapped: Promesses du produit
# This key has not been mapped: Défis du produit
# This key has not been mapped: Produit
# This key has not been mapped: Concurrence
# This key has not been mapped: Plan de l'Union Européenne
# This key has not been mapped: Prévision d'Exploitation
# This key has not been mapped: Situation de la Mère
# This key has not been mapped: Situation de l'Enfant
# This key has not been mapped: état du Conflit
# This key has not been mapped: Décisions de la Mère
# This key has not been mapped: Impact sur les Civils
# This key has not been mapped: Performance Militaire de la Russie
# This key has not been mapped: Prévisions de la Russie
# This key has not been mapped: Décisions de l'Ukraine
# This key has not been mapped: Position de l'OTAN
# This key has not been mapped: Déclarations Officielles Russes
# This key has not been mapped: Position du Président Ukrainien
# This key has not been mapped: Arguments Politiques
# This key has not been mapped: Arguments de la Majorité
# This key has not been mapped: Arguments de l'Opposition
# This key has not been mapped: Événements Politiques
# This key has not been mapped: Actions des Députés
# This key has not been mapped: Dynamique parmi Les Républicains
# This key has not been mapped: Résultat du Vote
# This key has not been mapped: Absence au Vote
# This key has not been mapped: Utilisation de l'Article Constitutionnel
# This key has not been mapped: Conflit Politique
# This key has not been mapped: Taxes
# This key has not been mapped: Position Politique de l'Entreprise
# This key has not been mapped: Situation Politique Générale
# This key has not been mapped: Gestion de l'Entreprise
# This key has not been mapped: Rôle des Acteurs Politiques
# This key has not been mapped: Actions Politiques
# This key has not been mapped: Perception Politique
# This key has not been mapped: Orientation Politique
# This key has not been mapped: Situation Energétique de l'Ukraine
# This key has not been mapped: Dommages Infrastructurels
# This key has not been mapped: Stratégie Militaire de l'Ukraine
# This key has not been mapped: Stratégie Militaire de la Russie
# This key has not been mapped: Inflation
# This key has not been mapped: Marché Géographique
# This key has not been mapped: Tension dans le Marché
# This key has not been mapped: Aide Financière
# This key has not been mapped: Taille du Navire
# This key has not been mapped: Type de Carburant
# This key has not been mapped: Réduction de l'Impact Environnemental
# This key has not been mapped: Opinion des Associations Écologistes

# %%
# Remapping if some variables not mapped
categories = list(variables_dict.keys())[1:]

dict_example = """

{
    "Public Reaction" : ["Manifestation", "Accident", "Taux de pauvreté"],
    "Economy" : ["Taux de pauvreté"],
    ...
}

"""

MAPPING_PROMPT = """ 

Je vais te donner une liste de variables. Une variable peut être affectée à une ou plusieurs catégories. J'aimerais que tu les regroupes dans les catégories suivantes.  :

Catégories: {categories}

---

Par exemple, si je te donne "Manifestation", "Accident", "Taux de pauvreté"...
Tu dois créer le dictionnaire suivant :

{example}

---

Voici la liste des variables :

Variables : {variables}


""".format(categories = "["+"".join(x + ", "for x in categories)+"]",variables = "["+"".join(x + ", "for x in not_mapped)+"]", example = dict_example)

res = request_gpt(MAPPING_PROMPT, "")

# %%
# Creation of the new dataframe where df[i,j] are the text from article i related to variable j
df_variables = pd.DataFrame()
for row in df_finance.iterrows():
    _dict = row[1].extraction
    new_dict = {}
    for key, value in _dict.items():
        if type(value)==list:
            value = " ".join(value)
        if value is None:
            value=""
        # Concatenate global key with the concatenation of values
        if key in variables_dict_inversed:
            for category in variables_dict_inversed[key]:
                if category not in new_dict:
                    new_dict[category] = value
                else:
                    new_dict[category] = new_dict[category] + " "+ value
        else:
            pass                 
    df_variables = pd.concat([df_variables, pd.DataFrame({row[0]: new_dict}).transpose()])

df_variables.to_csv("dataset_variable.csv", index=False)
df_variables
# Out:
#     Indicateur                                          Politique
# 0      NEGATIF  projet de réforme des retraites du gouvernemen...  \
# 1      POSITIF                                                NaN
# 2       NEUTRE  Directive sur la publication d'informations en...
# 3       NEUTRE  N/A majoration de la taxe d’habitation sur les...
# 4      POSITIF  Roxanne PAUSÉ DAMOUR, déléguée à la politique ...
# ..         ...                                                ...
# 382     NEUTRE                                                NaN
# 383    NEGATIF  Guerre Ukraine-Russie Guerre Ukraine-Russie Gu...
# 384    POSITIF  chiffre d'affaires envolé de 41,3%, ventes pro...
# 385     NEUTRE  Guerre en Ukraine, Critiques de démocrates amé...
# 386    POSITIF                                                NaN
#
#                                             Économique
# 0    entre un TGV sur trois et un TGV sur cinq selo...  \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 382                                                NaN
# 383                                                NaN
# 384  confirme ses objectifs annuels, augmenter à no...
# 385                                                NaN
# 386                                                NaN
#
#                                             Economique Changement Climatique
# 0                                                  NaN                   NaN  \
# 1    baisse 3,6 % quatrième trimestre 3,050 million...                   NaN
# 2    Vatican, Investissement responsable, liste de ...                   NaN
# 3    N/A N/A N/A N/A hausse du marché immobilier, d...                   NaN
# 4    PX1 ▲ +0,60%, PX4 ▲ +0,60%, CACAS ▲ +0,39%, EU...                   NaN
# ..                                                 ...                   ...
# 382                                                NaN                   NaN
# 383                                                NaN                   NaN
# 384  chiffre d'affaires envolé de 41,3%, ventes pro...                   NaN
# 385  Rejet des allégations russes par l'Otan, Fusti...                   NaN
# 386                                                NaN                   NaN
#
#     Social
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 382    NaN
# 383    NaN
# 384    NaN
# 385    NaN
# 386    NaN
#
# [387 rows x 6 columns]

# %% [markdown]
# # Encoding the values

# %%
# Function which transform "POSITIF" in 1, "NEUTRE" in 0, "NEGATIF" in "-1" 
def indicateur_transform(s):
    if s.lower()=="negatif":
        return -1
    if s.lower()=="positif":
        return 1
    return 0

# Function which use the openai API to encode a string 
def embed(string: str):
    if string=="":
        return np.NaN
    response = openai.Embedding.create(
        input=string,
        model="text-embedding-ada-002"
    )
    embeddings = response['data'][0]['embedding']
    return embeddings

# encoding of every value in the dataframe
df_variables_embed = df_variables.copy().drop(columns="Indicateur")
df_variables_embed.fillna("", inplace=True)
df_variables_embed = df_variables_embed.applymap(embed)
df_variables_embed["Indicateur"] = df_variables["Indicateur"].apply(indicateur_transform)
df_variables_embed.to_csv('dataset_variable_embeded.csv', index=False)

df_variables_embed
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[116], line 23
#      21 df_variables_embed = df_variables.copy().drop(columns="Indicateur")
#      22 df_variables_embed.fillna("", inplace=True)
# ---> 23 df_variables_embed = df_variables_embed.applymap(embed)
#      24 df_variables_embed["Indicateur"] = df_variables["Indicateur"].apply(indicateur_transform)
#      25 df_variables_embed.to_csv('dataset_variable_embeded.csv', index=False)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/core/frame.py:9513, in DataFrame.applymap(self, func, na_action, **kwargs)
#    9510         return lib.map_infer(x, func, ignore_na=ignore_na)
#    9511     return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
# -> 9513 return self.apply(infer).__finalize__(self, "applymap")
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/core/frame.py:9428, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9417 from pandas.core.apply import frame_apply
#    9419 op = frame_apply(
#    9420     self,
#    9421     func=func,
#    (...)
#    9426     kwargs=kwargs,
#    9427 )
# -> 9428 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/core/frame.py:9511, in DataFrame.applymap.<locals>.infer(x)
#    9509 if x.empty:
#    9510     return lib.map_infer(x, func, ignore_na=ignore_na)
# -> 9511 return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/pandas/_libs/lib.pyx:2834, in pandas._libs.lib.map_infer()
#
# Cell In[116], line 13, in embed(string)
#      11 if string=="":
#      12     return np.NaN
# ---> 13 response = openai.Embedding.create(
#      14     input=string,
#      15     model="text-embedding-ada-002"
#      16 )
#      17 embeddings = response['data'][0]['embedding']
#      18 return embeddings
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_resources/embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/openai/api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/envs/finance/lib/python3.11/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/anaconda3/envs/finance/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~/anaconda3/envs/finance/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/envs/finance/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/finance/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/envs/finance/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/finance/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # PCA reduction

# %%
# Transform vectors into reels: use of a PCA on each column but the "Indicateur" column which is already numeric
df_pca = df_variables_embed.copy()
for col in df_variables_embed.columns.drop("Indicateur"):
    _series = df_pca[col]
    _list_without_nan = list(_series[~_series.isna()])
    pca_coeff = pca_components_from_embeddings(_list_without_nan, 1)
    _series[~_series.isna()] = pca_coeff

df_pca.fillna(0, inplace=True)


col_abssum = df_pca.abs().sum()
df_pca = df_pca.loc[:,~(col_abssum==0)]
df_pca["Indicateur"] = df_variables["Indicateur"]
df_pca.to_csv("dataset_pca.csv", index=False)
